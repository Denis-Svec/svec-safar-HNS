# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
from PIL import Image

# %%
# Define the root directories for training and testing
train_dir = 'C:/Users/Patrik/Desktop/Files/fei/Ing/2nd class/HNS/project/Dataset_Znacky/Train-adj-train-test/train'
test_dir = 'C:/Users/Patrik/Desktop/Files/fei/Ing/2nd class/HNS/project/Dataset_Znacky/Train-adj-train-test/test'
num_classes = len(os.listdir(train_dir))

# Define transforms for data augmentation and normalization
data_transforms = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Create custom datasets for training and testing
train_dataset = datasets.ImageFolder(train_dir, transform=data_transforms)
test_dataset = datasets.ImageFolder(test_dir, transform=data_transforms)

# Create data loaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# Load the pre-trained AlexNet model
model = models.alexnet(pretrained=True)

for param in model.features.parameters():
    param.requires_grad = False
    
# Update the output layer to match the number of classes in your dataset
num_classes = 12  # Replace with the actual number of classes in your dataset
num_features = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_features, num_classes)
# Out:
# c:\Users\Patrik\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\Patrik\AppData\Local\Programs\Python\Python39\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt



device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = nn.CrossEntropyLoss()  
num_epochs = 20
accumulated_test_accuracies = []
num_classes = 12  


for run in range(3):  
    model.to(device)
    optimizer = optim.SGD(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001, momentum=0.9)
    
    train_loss_values = []
    val_loss_values = []

    for epoch in range(num_epochs):
        
        model.train()
        epoch_train_loss = 0.0
        for batch_idx, (data, targets) in enumerate(train_loader):
            data, targets = data.to(device), targets.to(device)

            outputs = model(data)
            loss = criterion(outputs, targets)
            epoch_train_loss += loss.item()

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            if batch_idx % 100 == 0:  
                print(f'Epoch [{epoch+1}/{num_epochs}], Step [{batch_idx}/{len(train_loader)}], Loss: {loss.item():.4f}')

            torch.cuda.empty_cache()
        avg_train_loss = epoch_train_loss / len(train_loader)
        train_loss_values.append(avg_train_loss)
        print(f'Epoch [{epoch+1}/{num_epochs}], Average Training Loss: {avg_train_loss:.4f}')

      
        model.eval()
        epoch_val_loss = 0.0
        with torch.no_grad():
            for batch_idx, (data, targets) in enumerate(test_loader): 
                data, targets = data.to(device), targets.to(device)

                outputs = model(data)
                loss = criterion(outputs, targets)
                epoch_val_loss += loss.item()
        avg_val_loss = epoch_val_loss / len(test_loader)
        val_loss_values.append(avg_val_loss)
        print(f'Epoch [{epoch+1}/{num_epochs}], Average Validation Loss: {avg_val_loss:.4f}')

    plt.plot(train_loss_values, label=f"Training Loss - Run {run+1}")
    plt.plot(val_loss_values, label=f"Validation Loss - Run {run+1}")

    print("Training complete.")
    model.eval()

    test_loss = 0.0
    correct = 0
    total = 0

  
    with torch.no_grad():
        for data, targets in test_loader:
            data, targets = data.to(device), targets.to(device)

          
            outputs = model(data)
            loss = criterion(outputs, targets)
            test_loss += loss.item()

       
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

    avg_test_loss = test_loss / len(test_loader)
    test_accuracy = 100 * correct / total
    accumulated_test_accuracies.append(test_accuracy)

    print(f"Run {run+1} Test Accuracy: {test_accuracy:.2f}%")


average_accuracy = sum(accumulated_test_accuracies) / 3

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss vs. Epoch')
plt.legend()
plt.show()
print(f"Average Test Accuracy over 3 runs: {average_accuracy:.2f}%")
# Out:
# Epoch [1/20], Step [0/755], Loss: 2.6391
# Epoch [1/20], Step [100/755], Loss: 1.2237
# Epoch [1/20], Step [200/755], Loss: 0.6987
# Epoch [1/20], Step [300/755], Loss: 0.8683
# Epoch [1/20], Step [400/755], Loss: 0.5372
# Epoch [1/20], Step [500/755], Loss: 0.7337
# Epoch [1/20], Step [600/755], Loss: 0.5184
# Epoch [1/20], Step [700/755], Loss: 0.5315
# Epoch [1/20], Average Training Loss: 0.8161
# Epoch [1/20], Average Validation Loss: 0.6520
# Epoch [2/20], Step [0/755], Loss: 0.5079
# Epoch [2/20], Step [100/755], Loss: 0.5357
# Epoch [2/20], Step [200/755], Loss: 0.8354
# Epoch [2/20], Step [300/755], Loss: 0.7480
# Epoch [2/20], Step [400/755], Loss: 0.8268
# Epoch [2/20], Step [500/755], Loss: 0.3668
# Epoch [2/20], Step [600/755], Loss: 0.4556
# Epoch [2/20], Step [700/755], Loss: 0.8329
# Epoch [2/20], Average Training Loss: 0.5721
# Epoch [2/20], Average Validation Loss: 0.5906
# Epoch [3/20], Step [0/755], Loss: 0.4538
# Epoch [3/20], Step [100/755], Loss: 0.8013
# Epoch [3/20], Step [200/755], Loss: 0.5039
# Epoch [3/20], Step [300/755], Loss: 0.6584
# Epoch [3/20], Step [400/755], Loss: 0.5436
# Epoch [3/20], Step [500/755], Loss: 0.4198
# Epoch [3/20], Step [600/755], Loss: 0.5690
# Epoch [3/20], Step [700/755], Loss: 0.5376
# Epoch [3/20], Average Training Loss: 0.5295
# Epoch [3/20], Average Validation Loss: 0.5620
# Epoch [4/20], Step [0/755], Loss: 0.4673
# Epoch [4/20], Step [100/755], Loss: 0.4445
# Epoch [4/20], Step [200/755], Loss: 0.4351
# Epoch [4/20], Step [300/755], Loss: 0.4711
# Epoch [4/20], Step [400/755], Loss: 0.6150
# Epoch [4/20], Step [500/755], Loss: 0.2873
# Epoch [4/20], Step [600/755], Loss: 0.7179
# Epoch [4/20], Step [700/755], Loss: 0.6016
# Epoch [4/20], Average Training Loss: 0.4928
# Epoch [4/20], Average Validation Loss: 0.5302
# Epoch [5/20], Step [0/755], Loss: 0.3859
# Epoch [5/20], Step [100/755], Loss: 0.5623
# Epoch [5/20], Step [200/755], Loss: 0.4783
# Epoch [5/20], Step [300/755], Loss: 0.6182
# Epoch [5/20], Step [400/755], Loss: 0.7925
# Epoch [5/20], Step [500/755], Loss: 0.4939
# Epoch [5/20], Step [600/755], Loss: 0.5663
# Epoch [5/20], Step [700/755], Loss: 0.3616
# Epoch [5/20], Average Training Loss: 0.4744
# Epoch [5/20], Average Validation Loss: 0.5087
# Epoch [6/20], Step [0/755], Loss: 0.3572
# Epoch [6/20], Step [100/755], Loss: 0.5123
# Epoch [6/20], Step [200/755], Loss: 0.2715
# Epoch [6/20], Step [300/755], Loss: 0.5477
# Epoch [6/20], Step [400/755], Loss: 0.4226
# Epoch [6/20], Step [500/755], Loss: 0.1074
# Epoch [6/20], Step [600/755], Loss: 0.3842
# Epoch [6/20], Step [700/755], Loss: 0.4159
# Epoch [6/20], Average Training Loss: 0.4594
# Epoch [6/20], Average Validation Loss: 0.5084
# Epoch [7/20], Step [0/755], Loss: 0.4095
# Epoch [7/20], Step [100/755], Loss: 0.4804
# Epoch [7/20], Step [200/755], Loss: 0.4908
# Epoch [7/20], Step [300/755], Loss: 0.4703
# Epoch [7/20], Step [400/755], Loss: 0.4815
# Epoch [7/20], Step [500/755], Loss: 0.3653
# Epoch [7/20], Step [600/755], Loss: 0.4432
# Epoch [7/20], Step [700/755], Loss: 0.4266
# Epoch [7/20], Average Training Loss: 0.4372
# Epoch [7/20], Average Validation Loss: 0.4831
# Epoch [8/20], Step [0/755], Loss: 0.5221
# Epoch [8/20], Step [100/755], Loss: 0.1358
# Epoch [8/20], Step [200/755], Loss: 0.4883
# Epoch [8/20], Step [300/755], Loss: 0.4486
# Epoch [8/20], Step [400/755], Loss: 0.7320
# Epoch [8/20], Step [500/755], Loss: 0.2604
# Epoch [8/20], Step [600/755], Loss: 0.5035
# Epoch [20/20], Step [600/755], Loss: 0.2351
# Epoch [20/20], Step [700/755], Loss: 0.5117
# Epoch [20/20], Average Training Loss: 0.3383
# Epoch [20/20], Average Validation Loss: 0.3899
# Training complete.
# Run 1 Test Accuracy: 85.61%
# Epoch [1/20], Step [0/755], Loss: 0.1236
# Epoch [1/20], Step [100/755], Loss: 0.4152
# Epoch [1/20], Step [200/755], Loss: 0.1801
# Epoch [1/20], Step [300/755], Loss: 0.1311
# Epoch [1/20], Step [400/755], Loss: 0.4632
# Epoch [1/20], Step [500/755], Loss: 0.3128
# Epoch [1/20], Step [600/755], Loss: 0.2869
# Epoch [1/20], Step [700/755], Loss: 0.4520
# Epoch [1/20], Average Training Loss: 0.3447
# Epoch [1/20], Average Validation Loss: 0.3806
# Epoch [2/20], Step [0/755], Loss: 0.4798
# Epoch [2/20], Step [100/755], Loss: 0.2054
# Epoch [2/20], Step [200/755], Loss: 0.2395
# Epoch [2/20], Step [300/755], Loss: 0.2091
# Epoch [2/20], Step [400/755], Loss: 0.1142
# Epoch [2/20], Step [500/755], Loss: 0.4408
# Epoch [2/20], Step [600/755], Loss: 0.2932
# Epoch [2/20], Step [700/755], Loss: 0.3776
# Epoch [2/20], Average Training Loss: 0.3387
# Epoch [2/20], Average Validation Loss: 0.3819
# Epoch [3/20], Step [0/755], Loss: 0.2329
# Epoch [3/20], Step [100/755], Loss: 0.3372
# Epoch [3/20], Step [200/755], Loss: 0.3683
# Epoch [3/20], Step [300/755], Loss: 0.0976
# Epoch [3/20], Step [400/755], Loss: 0.2956
# Epoch [3/20], Step [500/755], Loss: 0.3594
# Epoch [3/20], Step [600/755], Loss: 0.4140
# Epoch [3/20], Step [700/755], Loss: 0.3724
# Epoch [3/20], Average Training Loss: 0.3375
# Epoch [3/20], Average Validation Loss: 0.3864
# Epoch [4/20], Step [0/755], Loss: 0.4032
# Epoch [4/20], Step [100/755], Loss: 0.4438
# Epoch [4/20], Step [200/755], Loss: 0.3214
# Epoch [4/20], Step [300/755], Loss: 0.2431
# Epoch [4/20], Step [400/755], Loss: 0.3662
# Epoch [4/20], Step [500/755], Loss: 0.2766
# Epoch [4/20], Step [600/755], Loss: 0.2335
# Epoch [4/20], Step [700/755], Loss: 0.1430
# Epoch [4/20], Average Training Loss: 0.3346
# Epoch [4/20], Average Validation Loss: 0.3792
# Epoch [5/20], Step [0/755], Loss: 0.4678
# Epoch [5/20], Step [100/755], Loss: 0.2982
# Epoch [5/20], Step [200/755], Loss: 0.2943
# Epoch [5/20], Step [300/755], Loss: 0.2142
# Epoch [5/20], Step [400/755], Loss: 0.1976
# Epoch [5/20], Step [500/755], Loss: 0.2244
# Epoch [5/20], Step [600/755], Loss: 0.4743
# Epoch [5/20], Step [700/755], Loss: 0.4177
# Epoch [5/20], Average Training Loss: 0.3251
# Epoch [5/20], Average Validation Loss: 0.3799
# Epoch [6/20], Step [0/755], Loss: 0.3399
# Epoch [6/20], Step [100/755], Loss: 0.2929
# Epoch [6/20], Step [200/755], Loss: 0.2880
# Epoch [6/20], Step [300/755], Loss: 0.3642
# Epoch [18/20], Step [200/755], Loss: 0.3313
# Epoch [18/20], Step [300/755], Loss: 0.3160
# Epoch [18/20], Step [400/755], Loss: 0.2216
# Epoch [18/20], Step [500/755], Loss: 0.4277
# Epoch [18/20], Step [600/755], Loss: 0.2777
# Epoch [18/20], Step [700/755], Loss: 0.3102
# Epoch [18/20], Average Training Loss: 0.2928
# Epoch [18/20], Average Validation Loss: 0.3461
# Epoch [19/20], Step [0/755], Loss: 0.5881
# Epoch [19/20], Step [100/755], Loss: 0.3040
# Epoch [19/20], Step [200/755], Loss: 0.3316
# Epoch [19/20], Step [300/755], Loss: 0.2884
# Epoch [19/20], Step [400/755], Loss: 0.2736
# Epoch [19/20], Step [500/755], Loss: 0.2043
# Epoch [19/20], Step [600/755], Loss: 0.1414
# Epoch [19/20], Step [700/755], Loss: 0.2890
# Epoch [19/20], Average Training Loss: 0.2919
# Epoch [19/20], Average Validation Loss: 0.3406
# Epoch [20/20], Step [0/755], Loss: 0.2281
# Epoch [20/20], Step [100/755], Loss: 0.2605
# Epoch [20/20], Step [200/755], Loss: 0.2795
# Epoch [20/20], Step [300/755], Loss: 0.2555
# Epoch [20/20], Step [400/755], Loss: 0.1937
# Epoch [20/20], Step [500/755], Loss: 0.1626
# Epoch [20/20], Step [600/755], Loss: 0.1720
# Epoch [20/20], Step [700/755], Loss: 0.4129
# Epoch [20/20], Average Training Loss: 0.2863
# Epoch [20/20], Average Validation Loss: 0.3331
# Training complete.
# Run 2 Test Accuracy: 88.33%
# Epoch [1/20], Step [0/755], Loss: 0.3104
# Epoch [1/20], Step [100/755], Loss: 0.2457
# Epoch [1/20], Step [200/755], Loss: 0.3084
# Epoch [1/20], Step [300/755], Loss: 0.2754
# Epoch [1/20], Step [400/755], Loss: 0.1637
# Epoch [1/20], Step [500/755], Loss: 0.5064
# Epoch [1/20], Step [600/755], Loss: 0.6207
# Epoch [1/20], Step [700/755], Loss: 0.1859
# Epoch [1/20], Average Training Loss: 0.2854
# Epoch [1/20], Average Validation Loss: 0.3280
# Epoch [2/20], Step [0/755], Loss: 0.3220
# Epoch [2/20], Step [100/755], Loss: 0.3210
# Epoch [2/20], Step [200/755], Loss: 0.2846
# Epoch [2/20], Step [300/755], Loss: 0.2867
# Epoch [2/20], Step [400/755], Loss: 0.2252
# Epoch [2/20], Step [500/755], Loss: 0.2807
# Epoch [2/20], Step [600/755], Loss: 0.3477
# Epoch [2/20], Step [700/755], Loss: 0.2850
# Epoch [2/20], Average Training Loss: 0.2827
# Epoch [2/20], Average Validation Loss: 0.3206
# Epoch [3/20], Step [0/755], Loss: 0.2416
# Epoch [3/20], Step [100/755], Loss: 0.1820
# Epoch [3/20], Step [200/755], Loss: 0.2854
# Epoch [3/20], Step [300/755], Loss: 0.2610
# Epoch [3/20], Step [400/755], Loss: 0.2527
# Epoch [3/20], Step [500/755], Loss: 0.1842
# Epoch [3/20], Step [600/755], Loss: 0.3081
# Epoch [3/20], Step [700/755], Loss: 0.2474
# Epoch [3/20], Average Training Loss: 0.2873
# Epoch [3/20], Average Validation Loss: 0.3224
# Epoch [4/20], Step [0/755], Loss: 0.3300
# Epoch [4/20], Step [100/755], Loss: 0.2125
# Epoch [4/20], Step [200/755], Loss: 0.4014
# Epoch [4/20], Step [300/755], Loss: 0.1827
# Epoch [4/20], Step [400/755], Loss: 0.1573
# Epoch [4/20], Step [500/755], Loss: 0.3007
# Epoch [4/20], Step [600/755], Loss: 0.4538
# Epoch [4/20], Step [700/755], Loss: 0.1325
# Epoch [4/20], Average Training Loss: 0.2725
# Epoch [4/20], Average Validation Loss: 0.3284
# Epoch [5/20], Step [0/755], Loss: 0.3352
# Epoch [5/20], Step [100/755], Loss: 0.3803
# Epoch [5/20], Step [200/755], Loss: 0.4062
# Epoch [5/20], Step [300/755], Loss: 0.2231
# Epoch [5/20], Step [400/755], Loss: 0.1888
# Epoch [5/20], Step [500/755], Loss: 0.1288
# Epoch [5/20], Step [600/755], Loss: 0.1521
# Epoch [5/20], Step [700/755], Loss: 0.3650
# Epoch [5/20], Average Training Loss: 0.2867
# Epoch [5/20], Average Validation Loss: 0.3349
# Epoch [6/20], Step [0/755], Loss: 0.3116
# Epoch [6/20], Step [100/755], Loss: 0.1033
# Epoch [6/20], Step [200/755], Loss: 0.2584
# Epoch [6/20], Step [300/755], Loss: 0.0952
# Epoch [6/20], Step [400/755], Loss: 0.1396
# Epoch [6/20], Step [500/755], Loss: 0.4240
# Epoch [6/20], Step [600/755], Loss: 0.0721
# Epoch [6/20], Step [700/755], Loss: 0.0978
# Epoch [6/20], Average Training Loss: 0.2738
# Epoch [6/20], Average Validation Loss: 0.3355
# Epoch [7/20], Step [0/755], Loss: 0.2110
# Epoch [7/20], Step [100/755], Loss: 0.3899
# Epoch [7/20], Step [200/755], Loss: 0.2856
# Epoch [7/20], Step [300/755], Loss: 0.0794
# Epoch [7/20], Step [400/755], Loss: 0.2552
# Epoch [7/20], Step [500/755], Loss: 0.2713
# Epoch [7/20], Step [600/755], Loss: 0.2424
# Epoch [7/20], Step [700/755], Loss: 0.1144
# Epoch [7/20], Average Training Loss: 0.2834
# Epoch [7/20], Average Validation Loss: 0.3221
# Epoch [8/20], Step [0/755], Loss: 0.2848
# Epoch [8/20], Step [100/755], Loss: 0.4522
# Epoch [8/20], Step [200/755], Loss: 0.1226
# Epoch [8/20], Step [300/755], Loss: 0.0642
# Epoch [8/20], Step [400/755], Loss: 0.3944
# Epoch [8/20], Step [500/755], Loss: 0.3221
# Epoch [8/20], Step [600/755], Loss: 0.5223
# Epoch [8/20], Step [700/755], Loss: 0.2551
# Epoch [8/20], Average Training Loss: 0.2723
# Epoch [8/20], Average Validation Loss: 0.3241
# Epoch [9/20], Step [0/755], Loss: 0.3194
# Epoch [9/20], Step [100/755], Loss: 0.2461
# Epoch [9/20], Step [200/755], Loss: 0.3454
# Epoch [9/20], Step [300/755], Loss: 0.1791
# Epoch [9/20], Step [400/755], Loss: 0.3686
# Epoch [9/20], Step [500/755], Loss: 0.3567
# Epoch [9/20], Step [600/755], Loss: 0.2498
# Epoch [9/20], Step [700/755], Loss: 0.2089
# Epoch [9/20], Average Training Loss: 0.2717
# Epoch [9/20], Average Validation Loss: 0.3144
# Epoch [15/20], Average Validation Loss: 0.2945
# Epoch [16/20], Step [0/755], Loss: 0.5354
# Epoch [16/20], Step [100/755], Loss: 0.2528
# Epoch [16/20], Step [200/755], Loss: 0.2183
# Epoch [16/20], Step [300/755], Loss: 0.5019
# Epoch [16/20], Step [400/755], Loss: 0.1168
# Epoch [16/20], Step [500/755], Loss: 0.0695
# Epoch [16/20], Step [600/755], Loss: 0.3112
# Epoch [16/20], Step [700/755], Loss: 0.2057
# Epoch [16/20], Average Training Loss: 0.2635
# Epoch [16/20], Average Validation Loss: 0.3006
# Epoch [17/20], Step [0/755], Loss: 0.2030
# Epoch [17/20], Step [100/755], Loss: 0.2573
# Epoch [17/20], Step [200/755], Loss: 0.1196
# Epoch [17/20], Step [300/755], Loss: 0.1488
# Epoch [17/20], Step [400/755], Loss: 0.1098
# Epoch [17/20], Step [500/755], Loss: 0.2877
# Epoch [17/20], Step [600/755], Loss: 0.5348
# Epoch [17/20], Step [700/755], Loss: 0.3122
# Epoch [17/20], Average Training Loss: 0.2701
# Epoch [17/20], Average Validation Loss: 0.3221
# Epoch [18/20], Step [0/755], Loss: 0.3825
# Epoch [18/20], Step [100/755], Loss: 0.1763
# Epoch [18/20], Step [200/755], Loss: 0.0358
# Epoch [18/20], Step [300/755], Loss: 0.5440
# Epoch [18/20], Step [400/755], Loss: 0.1063
# Epoch [18/20], Step [500/755], Loss: 0.2702
# Epoch [18/20], Step [600/755], Loss: 0.1712
# Epoch [18/20], Step [700/755], Loss: 0.1652
# Epoch [18/20], Average Training Loss: 0.2594
# Epoch [18/20], Average Validation Loss: 0.3179
# Epoch [19/20], Step [0/755], Loss: 0.0573
# Epoch [19/20], Step [100/755], Loss: 0.2286
# Epoch [19/20], Step [200/755], Loss: 0.1226
# Epoch [19/20], Step [300/755], Loss: 0.4719
# Epoch [19/20], Step [400/755], Loss: 0.1251
# Epoch [19/20], Step [500/755], Loss: 0.5138
# Epoch [19/20], Step [600/755], Loss: 0.2197
# Epoch [19/20], Step [700/755], Loss: 0.2952
# Epoch [19/20], Average Training Loss: 0.2607
# Epoch [19/20], Average Validation Loss: 0.3061
# Epoch [20/20], Step [0/755], Loss: 0.1723
# Epoch [20/20], Step [100/755], Loss: 0.4470
# Epoch [20/20], Step [200/755], Loss: 0.2671
# Epoch [20/20], Step [300/755], Loss: 0.2205
# Epoch [20/20], Step [400/755], Loss: 0.4490
# Epoch [20/20], Step [500/755], Loss: 0.1995
# Epoch [20/20], Step [600/755], Loss: 0.4195
# Epoch [20/20], Step [700/755], Loss: 0.4450
# Epoch [20/20], Average Training Loss: 0.2614
# Epoch [20/20], Average Validation Loss: 0.3168
# Training complete.
# Run 3 Test Accuracy: 89.53%
# Average Test Accuracy over 3 runs: 87.82%

# %%
import itertools
import numpy as np

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(int(cm[i, j]), 'd'),
                horizontalalignment="center",
                color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    
confusion_matrix = np.zeros((num_classes, num_classes))
with torch.no_grad():
    for data, targets in test_loader:
        data, targets = data.to(device), targets.to(device)
        outputs = model(data)
        _, predicted = outputs.max(1)
        for t, p in zip(targets.view(-1), predicted.view(-1)):
            confusion_matrix[t.long(), p.long()] += 1

plot_confusion_matrix(confusion_matrix, list(range(num_classes)))
