# %%
import os
import torch
from torchvision import transforms
from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

class CustomDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        
        self.classes = os.listdir(self.root_dir)
        self.class_to_idx = {cls_name: i for i, cls_name in enumerate(self.classes)}
        self.paths = []
        self.labels = []

        for class_name in self.classes:
            class_dir = os.path.join(self.root_dir, class_name)
            for filename in os.listdir(class_dir):
                self.paths.append(os.path.join(class_dir, filename))
                self.labels.append(self.class_to_idx[class_name])

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, idx):
        image_path = self.paths[idx]
        label = self.labels[idx]

        image = Image.open(image_path)
        if self.transform:
            image = self.transform(image)

        return image, label
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\denis\Desktop\HNS\projekt1\git\CNN_1.ipynb Cell 1 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/denis/Desktop/HNS/projekt1/git/CNN_1.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import os
# ----> <a href='vscode-notebook-cell:/c%3A/Users/denis/Desktop/HNS/projekt1/git/CNN_1.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import torch
#       <a href='vscode-notebook-cell:/c%3A/Users/denis/Desktop/HNS/projekt1/git/CNN_1.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> from torchvision import transforms
#       <a href='vscode-notebook-cell:/c%3A/Users/denis/Desktop/HNS/projekt1/git/CNN_1.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> from PIL import Image
#
# ModuleNotFoundError: No module named 'torch'

# %%
class CustomImageDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        """
        Args:
            root_dir (string): Directory with all the images and their respective class folders.
            transform (callable, optional): Optional transform to be applied on an image.
        """
        self.root_dir = root_dir
        self.transform = transform
        
        # Create a list of file paths and their corresponding labels
        self.image_paths = []
        self.labels = []
        
        class_folders = [d for d in os.listdir(root_dir) if os.path.isdir(os.path.join(root_dir, d))]
        
        # Assign an integer label to each class/folder
        self.class_to_int = {c: idx for idx, c in enumerate(class_folders)}
        
        for class_folder in class_folders:
            folder_path = os.path.join(root_dir, class_folder)
            for file in os.listdir(folder_path):
                if file.endswith(('.jpg', '.png', '.jpeg')):
                    self.image_paths.append(os.path.join(folder_path, file))
                    self.labels.append(self.class_to_int[class_folder])

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        image = Image.open(image_path).convert("RGB")  # Convert grayscale images to RGB
        
        if self.transform:
            image = self.transform(image)
        
        label = self.labels[idx]
        return image, label

# Example usage:
transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor()
])

dataset = CustomImageDataset(root_dir='C:/Users/denis/Desktop/HNS/projekt1/Dataset_Znacky/Train-adj-train-test/train', transform=transform)
train_loader = DataLoader(dataset, batch_size=32, shuffle=True)

test_dataset = CustomImageDataset(root_dir='C:/Users/denis/Desktop/HNS/projekt1/Dataset_Znacky/Train-adj-train-test/test', transform=transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Get a sample from the dataset
image, label = dataset[0]
print(image.shape, label)
# Out:
# torch.Size([3, 64, 64]) 0

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import torch.nn.functional as F

# %%
# from torch.utils.data import DataLoader
# train_transforms = transforms.Compose([
#     transforms.Resize((64, 64)),
#     transforms.ToTensor()  
# ])

# dataset = CustomDataset(root_dir='C:/Users/denis/Desktop/HNS/projekt1/Dataset_Znacky/Train-adj/', transform = train_transforms)
# train_loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
# test_dataset = datasets.ImageFolder(os.path.dirname('C:/Users/denis/Desktop/HNS/projekt1/Dataset_Znacky/test-no-labels/'), transform = train_transforms)


# test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
class SimpleCNN_x(nn.Module):
    def __init__(self, num_classes=12):  
        super(SimpleCNN_x, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=5, stride=1, padding=2)
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=5, stride=1, padding=2)
        # self.conv1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, stride=1, padding=1)
        # self.conv2 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
        #self.conv3 = nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.dropout = nn.Dropout2d(p=0.2)
        self.fc1 = nn.Linear(163840, 524)  
        self.fc2 = nn.Linear(524, num_classes)

    def forward(self, x):
        x1 = F.leaky_relu(self.conv1(x))
        x1 = self.pool(x1)
        x2 = F.leaky_relu(self.conv2(x1))
        x3 = self.pool(x2)
        # x4 = self.pool(F.relu(self.conv3(x3)))
        # x4 = self.dropout(x4)
        x5 = x3.view(x3.size(0), -1) 
        xx = torch.cat([x5, torch.sin(x5)
        , torch.cos(x5), torch.sin(2 * x5), torch.cos(2 * x5)], dim=1) 
        x5 = self.dropout(xx)
        x6 = F.leaky_relu(self.fc1(x5))
        x6 = self.dropout(x6)
        out = self.fc2(x6)
        return x1, x2, out

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt



device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = nn.CrossEntropyLoss()  
num_epochs = 45
accumulated_test_accuracies = []
num_classes = 12  

for run in range(3):  
    model = SimpleCNN_x().to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.8)
    
    train_loss_values = []
    val_loss_values = []

    for epoch in range(num_epochs):
        
        model.train()
        epoch_train_loss = 0.0
        for batch_idx, (data, targets) in enumerate(train_loader):
            data, targets = data.to(device), targets.to(device)

            _, _, outputs = model(data)
            loss = criterion(outputs, targets)
            epoch_train_loss += loss.item()

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            if batch_idx % 100 == 0:  
                print(f'Epoch [{epoch+1}/{num_epochs}], Step [{batch_idx}/{len(train_loader)}], Loss: {loss.item():.4f}')

            torch.cuda.empty_cache()
        avg_train_loss = epoch_train_loss / len(train_loader)
        train_loss_values.append(avg_train_loss)
        print(f'Epoch [{epoch+1}/{num_epochs}], Average Training Loss: {avg_train_loss:.4f}')

      
        model.eval()
        epoch_val_loss = 0.0
        with torch.no_grad():
            for batch_idx, (data, targets) in enumerate(test_loader): 
                data, targets = data.to(device), targets.to(device)

                _, _, outputs = model(data)
                loss = criterion(outputs, targets)
                epoch_val_loss += loss.item()
        avg_val_loss = epoch_val_loss / len(test_loader)
        val_loss_values.append(avg_val_loss)
        print(f'Epoch [{epoch+1}/{num_epochs}], Average Validation Loss: {avg_val_loss:.4f}')

    plt.plot(train_loss_values, label=f"Training Loss - Run {run+1}")
    plt.plot(val_loss_values, label=f"Validation Loss - Run {run+1}")

    print("Training complete.")
    model.eval()

    test_loss = 0.0
    correct = 0
    total = 0

  
    with torch.no_grad():
        for data, targets in test_loader:
            data, targets = data.to(device), targets.to(device)

          
            _, _, outputs = model(data)
            loss = criterion(outputs, targets)
            test_loss += loss.item()

       
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

    avg_test_loss = test_loss / len(test_loader)
    test_accuracy = 100 * correct / total
    accumulated_test_accuracies.append(test_accuracy)

    print(f"Run {run+1} Test Accuracy: {test_accuracy:.2f}%")


average_accuracy = sum(accumulated_test_accuracies) / 3

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss vs. Epoch')
plt.legend()
plt.show()
print(f"Average Test Accuracy over 3 runs: {average_accuracy:.2f}%")
# Out:
# Epoch [1/45], Step [0/378], Loss: 2.4935
# Epoch [1/45], Step [100/378], Loss: 2.4749
# Epoch [1/45], Step [200/378], Loss: 2.3563
# Epoch [1/45], Step [300/378], Loss: 2.3054
# Epoch [1/45], Average Training Loss: 2.3507
# Epoch [1/45], Average Validation Loss: 2.3365
# Epoch [2/45], Step [0/378], Loss: 2.7907
# Epoch [2/45], Step [100/378], Loss: 2.3231
# Epoch [2/45], Step [200/378], Loss: 2.6088
# Epoch [2/45], Step [300/378], Loss: 2.3087
# Epoch [2/45], Average Training Loss: 2.2928
# Epoch [2/45], Average Validation Loss: 2.2118
# Epoch [3/45], Step [0/378], Loss: 2.2154
# Epoch [3/45], Step [100/378], Loss: 2.1823
# Epoch [3/45], Step [200/378], Loss: 2.1973
# Epoch [3/45], Step [300/378], Loss: 2.0438
# Epoch [3/45], Average Training Loss: 2.1128
# Epoch [3/45], Average Validation Loss: 1.7586
# Epoch [4/45], Step [0/378], Loss: 1.8501
# Epoch [4/45], Step [100/378], Loss: 1.6249
# Epoch [4/45], Step [200/378], Loss: 1.3039
# Epoch [4/45], Step [300/378], Loss: 1.1799
# Epoch [4/45], Average Training Loss: 1.4648
# Epoch [4/45], Average Validation Loss: 0.9743
# Epoch [5/45], Step [0/378], Loss: 1.2560
# Epoch [5/45], Step [100/378], Loss: 0.9346
# Epoch [5/45], Step [200/378], Loss: 0.6943
# Epoch [5/45], Step [300/378], Loss: 0.6503
# Epoch [5/45], Average Training Loss: 0.8539
# Epoch [5/45], Average Validation Loss: 0.5031
# Epoch [6/45], Step [0/378], Loss: 0.4803
# Epoch [6/45], Step [100/378], Loss: 0.5320
# Epoch [6/45], Step [200/378], Loss: 0.4791
# Epoch [6/45], Step [300/378], Loss: 0.3988
# Epoch [6/45], Average Training Loss: 0.4871
# Epoch [6/45], Average Validation Loss: 0.3075
# Epoch [7/45], Step [0/378], Loss: 0.3956
# Epoch [7/45], Step [100/378], Loss: 0.4252
# Epoch [7/45], Step [200/378], Loss: 0.2097
# Epoch [7/45], Step [300/378], Loss: 0.3618
# Epoch [7/45], Average Training Loss: 0.3092
# Epoch [7/45], Average Validation Loss: 0.1755
# Epoch [8/45], Step [0/378], Loss: 0.1790
# Epoch [8/45], Step [100/378], Loss: 0.1816
# Epoch [8/45], Step [200/378], Loss: 0.3112
# Epoch [8/45], Step [300/378], Loss: 0.1171
# Epoch [8/45], Average Training Loss: 0.2155
# Epoch [8/45], Average Validation Loss: 0.1461
# Epoch [9/45], Step [0/378], Loss: 0.1930
# Epoch [9/45], Step [100/378], Loss: 0.1071
# Epoch [9/45], Step [200/378], Loss: 0.1336
# Epoch [9/45], Step [300/378], Loss: 0.0582
# Epoch [9/45], Average Training Loss: 0.1566
# Epoch [9/45], Average Validation Loss: 0.1405
# Epoch [10/45], Step [0/378], Loss: 0.1004
# Epoch [10/45], Step [100/378], Loss: 0.0870
# Epoch [10/45], Step [200/378], Loss: 0.2041
# Epoch [10/45], Step [300/378], Loss: 0.0992
# Epoch [10/45], Average Training Loss: 0.1283
# Epoch [10/45], Average Validation Loss: 0.0921
# Epoch [11/45], Step [0/378], Loss: 0.0604
# Epoch [11/45], Step [100/378], Loss: 0.2031
# Epoch [11/45], Step [200/378], Loss: 0.1257
# Epoch [11/45], Step [300/378], Loss: 0.1484
# Epoch [11/45], Average Training Loss: 0.1091
# Epoch [11/45], Average Validation Loss: 0.0782
# Epoch [12/45], Step [0/378], Loss: 0.0660
# Epoch [12/45], Step [100/378], Loss: 0.1202
# Epoch [12/45], Step [200/378], Loss: 0.0932
# Epoch [12/45], Step [300/378], Loss: 0.3041
# Epoch [12/45], Average Training Loss: 0.0883
# Epoch [12/45], Average Validation Loss: 0.0813
# Epoch [13/45], Step [0/378], Loss: 0.1094
# Epoch [13/45], Step [100/378], Loss: 0.0505
# Epoch [13/45], Step [200/378], Loss: 0.0364
# Epoch [13/45], Step [300/378], Loss: 0.1127
# Epoch [13/45], Average Training Loss: 0.0782
# Epoch [13/45], Average Validation Loss: 0.0591
# Epoch [14/45], Step [0/378], Loss: 0.0178
# Epoch [14/45], Step [100/378], Loss: 0.0096
# Epoch [14/45], Step [200/378], Loss: 0.0480
# Epoch [14/45], Step [300/378], Loss: 0.0597
# Epoch [14/45], Average Training Loss: 0.0683
# Epoch [14/45], Average Validation Loss: 0.0523
# Epoch [15/45], Step [0/378], Loss: 0.0056
# Epoch [15/45], Step [100/378], Loss: 0.1023
# Epoch [15/45], Step [200/378], Loss: 0.0420
# Epoch [15/45], Step [300/378], Loss: 0.0413
# Epoch [15/45], Average Training Loss: 0.0649
# Epoch [15/45], Average Validation Loss: 0.0588
# Epoch [16/45], Step [0/378], Loss: 0.0656
# Epoch [16/45], Step [100/378], Loss: 0.2056
# Epoch [16/45], Step [200/378], Loss: 0.0867
# Epoch [16/45], Step [300/378], Loss: 0.0475
# Epoch [16/45], Average Training Loss: 0.0563
# Epoch [16/45], Average Validation Loss: 0.0482
# Epoch [17/45], Step [0/378], Loss: 0.0109
# Epoch [17/45], Step [100/378], Loss: 0.1293
# Epoch [17/45], Step [200/378], Loss: 0.0313
# Epoch [17/45], Step [300/378], Loss: 0.0747
# Epoch [17/45], Average Training Loss: 0.0493
# Epoch [17/45], Average Validation Loss: 0.0447
# Epoch [18/45], Step [0/378], Loss: 0.0013
# Epoch [18/45], Step [100/378], Loss: 0.0336
# Epoch [18/45], Step [200/378], Loss: 0.0376
# Epoch [18/45], Step [300/378], Loss: 0.0614
# Epoch [18/45], Average Training Loss: 0.0432
# Epoch [18/45], Average Validation Loss: 0.0502
# Epoch [19/45], Step [0/378], Loss: 0.0099
# Epoch [19/45], Step [100/378], Loss: 0.1109
# Epoch [19/45], Step [200/378], Loss: 0.0075
# Epoch [19/45], Step [300/378], Loss: 0.0102
# Epoch [19/45], Average Training Loss: 0.0420
# Epoch [19/45], Average Validation Loss: 0.0545
# Epoch [20/45], Step [0/378], Loss: 0.0113
# Epoch [20/45], Step [100/378], Loss: 0.0131
# Epoch [20/45], Step [200/378], Loss: 0.0015
# Epoch [20/45], Step [300/378], Loss: 0.0255
# Epoch [20/45], Average Training Loss: 0.0356
# Epoch [20/45], Average Validation Loss: 0.0673
# Epoch [21/45], Step [0/378], Loss: 0.0562
# Epoch [21/45], Step [100/378], Loss: 0.0346
# Epoch [21/45], Step [200/378], Loss: 0.0089
# Epoch [21/45], Step [300/378], Loss: 0.0099
# Epoch [21/45], Average Training Loss: 0.0349
# Epoch [21/45], Average Validation Loss: 0.0467
# Epoch [22/45], Step [0/378], Loss: 0.0107
# Epoch [22/45], Step [100/378], Loss: 0.0050
# Epoch [22/45], Step [200/378], Loss: 0.0036
# Epoch [22/45], Step [300/378], Loss: 0.0070
# Epoch [22/45], Average Training Loss: 0.0325
# Epoch [22/45], Average Validation Loss: 0.0440
# Epoch [23/45], Step [0/378], Loss: 0.0490
# Epoch [23/45], Step [100/378], Loss: 0.0030
# Epoch [23/45], Step [200/378], Loss: 0.0073
# Epoch [23/45], Step [300/378], Loss: 0.0295
# Epoch [23/45], Average Training Loss: 0.0315
# Epoch [23/45], Average Validation Loss: 0.0495
# Epoch [24/45], Step [0/378], Loss: 0.0151
# Epoch [24/45], Step [100/378], Loss: 0.1222
# Epoch [24/45], Step [200/378], Loss: 0.0073
# Epoch [24/45], Step [300/378], Loss: 0.0091
# Epoch [24/45], Average Training Loss: 0.0301
# Epoch [24/45], Average Validation Loss: 0.0401
# Epoch [25/45], Step [0/378], Loss: 0.0256
# Epoch [25/45], Step [100/378], Loss: 0.0123
# Epoch [25/45], Step [200/378], Loss: 0.0136
# Epoch [25/45], Step [300/378], Loss: 0.0373
# Epoch [25/45], Average Training Loss: 0.0299
# Epoch [25/45], Average Validation Loss: 0.0376
# Epoch [26/45], Step [0/378], Loss: 0.0046
# Epoch [26/45], Step [100/378], Loss: 0.0695
# Epoch [26/45], Step [200/378], Loss: 0.0019
# Epoch [26/45], Step [300/378], Loss: 0.3670
# Epoch [26/45], Average Training Loss: 0.0283
# Epoch [26/45], Average Validation Loss: 0.0356
# Epoch [27/45], Step [0/378], Loss: 0.0036
# Epoch [27/45], Step [100/378], Loss: 0.0078
# Epoch [27/45], Step [200/378], Loss: 0.0032
# Epoch [27/45], Step [300/378], Loss: 0.0064
# Epoch [27/45], Average Training Loss: 0.0262
# Epoch [27/45], Average Validation Loss: 0.0360
# Epoch [28/45], Step [0/378], Loss: 0.0133
# Epoch [28/45], Step [100/378], Loss: 0.0074
# Epoch [28/45], Step [200/378], Loss: 0.0054
# Epoch [28/45], Step [300/378], Loss: 0.0040
# Epoch [28/45], Average Training Loss: 0.0245
# Epoch [28/45], Average Validation Loss: 0.0402
# Epoch [29/45], Step [0/378], Loss: 0.0533
# Epoch [29/45], Step [100/378], Loss: 0.0088
# Epoch [29/45], Step [200/378], Loss: 0.1015
# Epoch [29/45], Step [300/378], Loss: 0.0038
# Epoch [29/45], Average Training Loss: 0.0251
# Epoch [29/45], Average Validation Loss: 0.0360
# Epoch [30/45], Step [0/378], Loss: 0.0120
# Epoch [30/45], Step [100/378], Loss: 0.0023
# Epoch [30/45], Step [200/378], Loss: 0.0051
# Epoch [30/45], Step [300/378], Loss: 0.0199
# Epoch [30/45], Average Training Loss: 0.0244
# Epoch [30/45], Average Validation Loss: 0.0390
# Epoch [31/45], Step [0/378], Loss: 0.0059
# Epoch [31/45], Step [100/378], Loss: 0.0057
# Epoch [31/45], Step [200/378], Loss: 0.0835
# Epoch [31/45], Step [300/378], Loss: 0.0155
# Epoch [31/45], Average Training Loss: 0.0239
# Epoch [31/45], Average Validation Loss: 0.0344
# Epoch [32/45], Step [0/378], Loss: 0.0077
# Epoch [32/45], Step [100/378], Loss: 0.0560
# Epoch [32/45], Step [200/378], Loss: 0.0101
# Epoch [32/45], Step [300/378], Loss: 0.0002
# Epoch [32/45], Average Training Loss: 0.0201
# Epoch [32/45], Average Validation Loss: 0.0317
# Epoch [33/45], Step [0/378], Loss: 0.0135
# Epoch [33/45], Step [100/378], Loss: 0.0068
# Epoch [33/45], Step [200/378], Loss: 0.0024
# Epoch [33/45], Step [300/378], Loss: 0.0821
# Epoch [33/45], Average Training Loss: 0.0181
# Epoch [33/45], Average Validation Loss: 0.0332
# Epoch [34/45], Step [0/378], Loss: 0.0165
# Epoch [34/45], Step [100/378], Loss: 0.0019
# Epoch [34/45], Step [200/378], Loss: 0.0130
# Epoch [34/45], Step [300/378], Loss: 0.1282
# Epoch [34/45], Average Training Loss: 0.0242
# Epoch [34/45], Average Validation Loss: 0.0320
# Epoch [35/45], Step [0/378], Loss: 0.0034
# Epoch [35/45], Step [100/378], Loss: 0.0002
# Epoch [35/45], Step [200/378], Loss: 0.0111
# Epoch [35/45], Step [300/378], Loss: 0.0072
# Epoch [35/45], Average Training Loss: 0.0188
# Epoch [35/45], Average Validation Loss: 0.0336
# Epoch [36/45], Step [0/378], Loss: 0.0005
# Epoch [36/45], Step [100/378], Loss: 0.0013
# Epoch [36/45], Step [200/378], Loss: 0.0022
# Epoch [36/45], Step [300/378], Loss: 0.0244
# Epoch [36/45], Average Training Loss: 0.0175
# Epoch [36/45], Average Validation Loss: 0.0306
# Epoch [37/45], Step [0/378], Loss: 0.0004
# Epoch [37/45], Step [100/378], Loss: 0.0084
# Epoch [37/45], Step [200/378], Loss: 0.0168
# Epoch [37/45], Step [300/378], Loss: 0.0049
# Epoch [37/45], Average Training Loss: 0.0193
# Epoch [37/45], Average Validation Loss: 0.0374
# Epoch [38/45], Step [0/378], Loss: 0.0009
# Epoch [38/45], Step [100/378], Loss: 0.0039
# Epoch [38/45], Step [200/378], Loss: 0.0418
# Epoch [38/45], Step [300/378], Loss: 0.0021
# Epoch [38/45], Average Training Loss: 0.0208
# Epoch [38/45], Average Validation Loss: 0.0338
# Epoch [39/45], Step [0/378], Loss: 0.0020
# Epoch [39/45], Step [100/378], Loss: 0.0020
# Epoch [39/45], Step [200/378], Loss: 0.0111
# Epoch [39/45], Step [300/378], Loss: 0.0204
# Epoch [39/45], Average Training Loss: 0.0166
# Epoch [39/45], Average Validation Loss: 0.0412
# Epoch [40/45], Step [0/378], Loss: 0.0118
# Epoch [40/45], Step [100/378], Loss: 0.0557
# Epoch [40/45], Step [200/378], Loss: 0.0001
# Epoch [40/45], Step [300/378], Loss: 0.0126
# Epoch [40/45], Average Training Loss: 0.0182
# Epoch [40/45], Average Validation Loss: 0.0342
# Epoch [41/45], Step [0/378], Loss: 0.0026
# Epoch [41/45], Step [100/378], Loss: 0.1680
# Epoch [41/45], Step [200/378], Loss: 0.0008
# Epoch [41/45], Step [300/378], Loss: 0.0910
# Epoch [41/45], Average Training Loss: 0.0176
# Epoch [41/45], Average Validation Loss: 0.0337
# Epoch [42/45], Step [0/378], Loss: 0.0136
# Epoch [42/45], Step [100/378], Loss: 0.0003
# Epoch [42/45], Step [200/378], Loss: 0.0274
# Epoch [42/45], Step [300/378], Loss: 0.0459
# Epoch [42/45], Average Training Loss: 0.0150
# Epoch [42/45], Average Validation Loss: 0.0291
# Epoch [43/45], Step [0/378], Loss: 0.0018
# Epoch [43/45], Step [100/378], Loss: 0.0002
# Epoch [43/45], Step [200/378], Loss: 0.0126
# Epoch [43/45], Step [300/378], Loss: 0.0104
# Epoch [43/45], Average Training Loss: 0.0162
# Epoch [43/45], Average Validation Loss: 0.0328
# Epoch [44/45], Step [0/378], Loss: 0.0035
# Epoch [44/45], Step [100/378], Loss: 0.0246
# Epoch [44/45], Step [200/378], Loss: 0.0224
# Epoch [44/45], Step [300/378], Loss: 0.0384
# Epoch [44/45], Average Training Loss: 0.0166
# Epoch [44/45], Average Validation Loss: 0.0304
# Epoch [45/45], Step [0/378], Loss: 0.0021
# Epoch [45/45], Step [100/378], Loss: 0.0018
# Epoch [45/45], Step [200/378], Loss: 0.0006
# Epoch [45/45], Step [300/378], Loss: 0.0289
# Epoch [45/45], Average Training Loss: 0.0155
# Epoch [45/45], Average Validation Loss: 0.0336
# Training complete.
# Run 1 Test Accuracy: 99.11%
# Epoch [1/45], Step [0/378], Loss: 2.4853
# Epoch [1/45], Step [100/378], Loss: 2.3587
# Epoch [1/45], Step [200/378], Loss: 2.3835
# Epoch [1/45], Step [300/378], Loss: 2.2988
# Epoch [1/45], Average Training Loss: 2.3501
# Epoch [1/45], Average Validation Loss: 2.3116
# Epoch [2/45], Step [0/378], Loss: 2.1185
# Epoch [2/45], Step [100/378], Loss: 2.3668
# Epoch [2/45], Step [200/378], Loss: 2.2046
# Epoch [2/45], Step [300/378], Loss: 2.2082
# Epoch [2/45], Average Training Loss: 2.2858
# Epoch [2/45], Average Validation Loss: 2.2296
# Epoch [3/45], Step [0/378], Loss: 2.0463
# Epoch [3/45], Step [100/378], Loss: 2.5026
# Epoch [3/45], Step [200/378], Loss: 1.9625
# Epoch [3/45], Step [300/378], Loss: 1.6866
# Epoch [3/45], Average Training Loss: 2.0037
# Epoch [3/45], Average Validation Loss: 1.5614
# Epoch [4/45], Step [0/378], Loss: 1.5348
# Epoch [4/45], Step [100/378], Loss: 1.3233
# Epoch [4/45], Step [200/378], Loss: 1.2276
# Epoch [4/45], Step [300/378], Loss: 0.9308
# Epoch [4/45], Average Training Loss: 1.2328
# Epoch [4/45], Average Validation Loss: 0.7851
# Epoch [5/45], Step [0/378], Loss: 0.7001
# Epoch [5/45], Step [100/378], Loss: 0.6312
# Epoch [5/45], Step [200/378], Loss: 0.6832
# Epoch [5/45], Step [300/378], Loss: 0.7375
# Epoch [5/45], Average Training Loss: 0.7252
# Epoch [5/45], Average Validation Loss: 0.4977
# Epoch [6/45], Step [0/378], Loss: 0.5471
# Epoch [6/45], Step [100/378], Loss: 0.5343
# Epoch [6/45], Step [200/378], Loss: 0.8669
# Epoch [6/45], Step [300/378], Loss: 0.8619
# Epoch [6/45], Average Training Loss: 0.4500
# Epoch [6/45], Average Validation Loss: 0.2946
# Epoch [7/45], Step [0/378], Loss: 0.1932
# Epoch [7/45], Step [100/378], Loss: 0.7908
# Epoch [7/45], Step [200/378], Loss: 0.3116
# Epoch [7/45], Step [300/378], Loss: 0.2813
# Epoch [7/45], Average Training Loss: 0.3021
# Epoch [7/45], Average Validation Loss: 0.2575
# Epoch [8/45], Step [0/378], Loss: 0.1188
# Epoch [8/45], Step [100/378], Loss: 0.2388
# Epoch [8/45], Step [200/378], Loss: 0.3132
# Epoch [8/45], Step [300/378], Loss: 0.2309
# Epoch [8/45], Average Training Loss: 0.2095
# Epoch [8/45], Average Validation Loss: 0.1389
# Epoch [9/45], Step [0/378], Loss: 0.0927
# Epoch [9/45], Step [100/378], Loss: 0.3527
# Epoch [9/45], Step [200/378], Loss: 0.1531
# Epoch [9/45], Step [300/378], Loss: 0.0671
# Epoch [9/45], Average Training Loss: 0.1690
# Epoch [9/45], Average Validation Loss: 0.1256
# Epoch [10/45], Step [0/378], Loss: 0.2666
# Epoch [10/45], Step [100/378], Loss: 0.0344
# Epoch [10/45], Step [200/378], Loss: 0.0866
# Epoch [10/45], Step [300/378], Loss: 0.0439
# Epoch [10/45], Average Training Loss: 0.1277
# Epoch [10/45], Average Validation Loss: 0.1010
# Epoch [11/45], Step [0/378], Loss: 0.1410
# Epoch [11/45], Step [100/378], Loss: 0.1148
# Epoch [11/45], Step [200/378], Loss: 0.0155
# Epoch [11/45], Step [300/378], Loss: 0.0710
# Epoch [11/45], Average Training Loss: 0.1047
# Epoch [11/45], Average Validation Loss: 0.1690
# Epoch [12/45], Step [0/378], Loss: 0.3195
# Epoch [12/45], Step [100/378], Loss: 0.0859
# Epoch [12/45], Step [200/378], Loss: 0.4876
# Epoch [12/45], Step [300/378], Loss: 0.0246
# Epoch [12/45], Average Training Loss: 0.0870
# Epoch [12/45], Average Validation Loss: 0.0827
# Epoch [13/45], Step [0/378], Loss: 0.0319
# Epoch [13/45], Step [100/378], Loss: 0.1374
# Epoch [13/45], Step [200/378], Loss: 0.0332
# Epoch [13/45], Step [300/378], Loss: 0.2042
# Epoch [13/45], Average Training Loss: 0.0777
# Epoch [13/45], Average Validation Loss: 0.0695
# Epoch [14/45], Step [0/378], Loss: 0.2178
# Epoch [14/45], Step [100/378], Loss: 0.1834
# Epoch [14/45], Step [200/378], Loss: 0.0147
# Epoch [14/45], Step [300/378], Loss: 0.3491
# Epoch [14/45], Average Training Loss: 0.0625
# Epoch [14/45], Average Validation Loss: 0.0614
# Epoch [15/45], Step [0/378], Loss: 0.0086
# Epoch [15/45], Step [100/378], Loss: 0.0287
# Epoch [15/45], Step [200/378], Loss: 0.2445
# Epoch [15/45], Step [300/378], Loss: 0.1066
# Epoch [15/45], Average Training Loss: 0.0601
# Epoch [15/45], Average Validation Loss: 0.0698
# Epoch [16/45], Step [0/378], Loss: 0.0185
# Epoch [16/45], Step [100/378], Loss: 0.0524
# Epoch [16/45], Step [200/378], Loss: 0.0296
# Epoch [16/45], Step [300/378], Loss: 0.2988
# Epoch [16/45], Average Training Loss: 0.0544
# Epoch [16/45], Average Validation Loss: 0.0638
# Epoch [17/45], Step [0/378], Loss: 0.0885
# Epoch [17/45], Step [100/378], Loss: 0.0252
# Epoch [17/45], Step [200/378], Loss: 0.0114
# Epoch [17/45], Step [300/378], Loss: 0.0376
# Epoch [17/45], Average Training Loss: 0.0482
# Epoch [17/45], Average Validation Loss: 0.0488
# Epoch [18/45], Step [0/378], Loss: 0.0082
# Epoch [18/45], Step [100/378], Loss: 0.2211
# Epoch [18/45], Step [200/378], Loss: 0.1117
# Epoch [18/45], Step [300/378], Loss: 0.0043
# Epoch [18/45], Average Training Loss: 0.0443
# Epoch [18/45], Average Validation Loss: 0.0499
# Epoch [19/45], Step [0/378], Loss: 0.0234
# Epoch [19/45], Step [100/378], Loss: 0.0657
# Epoch [19/45], Step [200/378], Loss: 0.0034
# Epoch [19/45], Step [300/378], Loss: 0.0048
# Epoch [19/45], Average Training Loss: 0.0385
# Epoch [19/45], Average Validation Loss: 0.0508
# Epoch [20/45], Step [0/378], Loss: 0.0324
# Epoch [20/45], Step [100/378], Loss: 0.0108
# Epoch [20/45], Step [200/378], Loss: 0.0041
# Epoch [20/45], Step [300/378], Loss: 0.1186
# Epoch [20/45], Average Training Loss: 0.0379
# Epoch [20/45], Average Validation Loss: 0.0424
# Epoch [21/45], Step [0/378], Loss: 0.0055
# Epoch [21/45], Step [100/378], Loss: 0.0044
# Epoch [21/45], Step [200/378], Loss: 0.1347
# Epoch [21/45], Step [300/378], Loss: 0.0017
# Epoch [21/45], Average Training Loss: 0.0357
# Epoch [21/45], Average Validation Loss: 0.0465
# Epoch [22/45], Step [0/378], Loss: 0.0230
# Epoch [22/45], Step [100/378], Loss: 0.0082
# Epoch [22/45], Step [200/378], Loss: 0.0383
# Epoch [22/45], Step [300/378], Loss: 0.0046
# Epoch [22/45], Average Training Loss: 0.0339
# Epoch [22/45], Average Validation Loss: 0.0517
# Epoch [23/45], Step [0/378], Loss: 0.0107
# Epoch [23/45], Step [100/378], Loss: 0.0058
# Epoch [23/45], Step [200/378], Loss: 0.0067
# Epoch [23/45], Step [300/378], Loss: 0.0555
# Epoch [23/45], Average Training Loss: 0.0325
# Epoch [23/45], Average Validation Loss: 0.0558
# Epoch [24/45], Step [0/378], Loss: 0.0028
# Epoch [24/45], Step [100/378], Loss: 0.0043
# Epoch [24/45], Step [200/378], Loss: 0.0026
# Epoch [24/45], Step [300/378], Loss: 0.0559
# Epoch [24/45], Average Training Loss: 0.0294
# Epoch [24/45], Average Validation Loss: 0.0503
# Epoch [25/45], Step [0/378], Loss: 0.0753
# Epoch [25/45], Step [100/378], Loss: 0.0056
# Epoch [25/45], Step [200/378], Loss: 0.0284
# Epoch [25/45], Step [300/378], Loss: 0.0094
# Epoch [25/45], Average Training Loss: 0.0321
# Epoch [25/45], Average Validation Loss: 0.0465
# Epoch [26/45], Step [0/378], Loss: 0.1317
# Epoch [26/45], Step [100/378], Loss: 0.0073
# Epoch [26/45], Step [200/378], Loss: 0.0290
# Epoch [26/45], Step [300/378], Loss: 0.0003
# Epoch [26/45], Average Training Loss: 0.0258
# Epoch [26/45], Average Validation Loss: 0.0631
# Epoch [27/45], Step [0/378], Loss: 0.0013
# Epoch [27/45], Step [100/378], Loss: 0.0020
# Epoch [27/45], Step [200/378], Loss: 0.0233
# Epoch [27/45], Step [300/378], Loss: 0.0047
# Epoch [27/45], Average Training Loss: 0.0253
# Epoch [27/45], Average Validation Loss: 0.0410
# Epoch [28/45], Step [0/378], Loss: 0.0744
# Epoch [28/45], Step [100/378], Loss: 0.1301
# Epoch [28/45], Step [200/378], Loss: 0.0086
# Epoch [28/45], Step [300/378], Loss: 0.0707
# Epoch [28/45], Average Training Loss: 0.0231
# Epoch [28/45], Average Validation Loss: 0.0418
# Epoch [29/45], Step [0/378], Loss: 0.0596
# Epoch [29/45], Step [100/378], Loss: 0.0015
# Epoch [29/45], Step [200/378], Loss: 0.0202
# Epoch [29/45], Step [300/378], Loss: 0.0207
# Epoch [29/45], Average Training Loss: 0.0229
# Epoch [29/45], Average Validation Loss: 0.0433
# Epoch [30/45], Step [0/378], Loss: 0.1055
# Epoch [30/45], Step [100/378], Loss: 0.0083
# Epoch [30/45], Step [200/378], Loss: 0.0024
# Epoch [30/45], Step [300/378], Loss: 0.0022
# Epoch [30/45], Average Training Loss: 0.0216
# Epoch [30/45], Average Validation Loss: 0.0442
# Epoch [31/45], Step [0/378], Loss: 0.0236
# Epoch [31/45], Step [100/378], Loss: 0.0047
# Epoch [31/45], Step [200/378], Loss: 0.0534
# Epoch [31/45], Step [300/378], Loss: 0.0283
# Epoch [31/45], Average Training Loss: 0.0199
# Epoch [31/45], Average Validation Loss: 0.0405
# Epoch [32/45], Step [0/378], Loss: 0.0223
# Epoch [32/45], Step [100/378], Loss: 0.0019
# Epoch [32/45], Step [200/378], Loss: 0.0020
# Epoch [32/45], Step [300/378], Loss: 0.0110
# Epoch [32/45], Average Training Loss: 0.0248
# Epoch [32/45], Average Validation Loss: 0.0367
# Epoch [33/45], Step [0/378], Loss: 0.0433
# Epoch [33/45], Step [100/378], Loss: 0.0008
# Epoch [33/45], Step [200/378], Loss: 0.0023
# Epoch [33/45], Step [300/378], Loss: 0.0181
# Epoch [33/45], Average Training Loss: 0.0200
# Epoch [33/45], Average Validation Loss: 0.0380
# Epoch [34/45], Step [0/378], Loss: 0.0512
# Epoch [34/45], Step [100/378], Loss: 0.0893
# Epoch [34/45], Step [200/378], Loss: 0.0004
# Epoch [34/45], Step [300/378], Loss: 0.0268
# Epoch [34/45], Average Training Loss: 0.0202
# Epoch [34/45], Average Validation Loss: 0.0328
# Epoch [35/45], Step [0/378], Loss: 0.0017
# Epoch [35/45], Step [100/378], Loss: 0.0036
# Epoch [35/45], Step [200/378], Loss: 0.0022
# Epoch [35/45], Step [300/378], Loss: 0.1108
# Epoch [35/45], Average Training Loss: 0.0182
# Epoch [35/45], Average Validation Loss: 0.0352
# Epoch [36/45], Step [0/378], Loss: 0.0007
# Epoch [36/45], Step [100/378], Loss: 0.0522
# Epoch [36/45], Step [200/378], Loss: 0.0025
# Epoch [36/45], Step [300/378], Loss: 0.2549
# Epoch [36/45], Average Training Loss: 0.0190
# Epoch [36/45], Average Validation Loss: 0.0391
# Epoch [37/45], Step [0/378], Loss: 0.0029
# Epoch [37/45], Step [100/378], Loss: 0.0010
# Epoch [37/45], Step [200/378], Loss: 0.1028
# Epoch [37/45], Step [300/378], Loss: 0.0022
# Epoch [37/45], Average Training Loss: 0.0177
# Epoch [37/45], Average Validation Loss: 0.0359
# Epoch [38/45], Step [0/378], Loss: 0.0382
# Epoch [38/45], Step [100/378], Loss: 0.0096
# Epoch [38/45], Step [200/378], Loss: 0.0183
# Epoch [38/45], Step [300/378], Loss: 0.0063
# Epoch [38/45], Average Training Loss: 0.0195
# Epoch [38/45], Average Validation Loss: 0.0416
# Epoch [39/45], Step [0/378], Loss: 0.0069
# Epoch [39/45], Step [100/378], Loss: 0.0316
# Epoch [39/45], Step [200/378], Loss: 0.0081
# Epoch [39/45], Step [300/378], Loss: 0.0017
# Epoch [39/45], Average Training Loss: 0.0175
# Epoch [39/45], Average Validation Loss: 0.0412
# Epoch [40/45], Step [0/378], Loss: 0.0796
# Epoch [40/45], Step [100/378], Loss: 0.0043
# Epoch [40/45], Step [200/378], Loss: 0.0185
# Epoch [40/45], Step [300/378], Loss: 0.0019
# Epoch [40/45], Average Training Loss: 0.0170
# Epoch [40/45], Average Validation Loss: 0.0329
# Epoch [41/45], Step [0/378], Loss: 0.0080
# Epoch [41/45], Step [100/378], Loss: 0.0335
# Epoch [41/45], Step [200/378], Loss: 0.0004
# Epoch [41/45], Step [300/378], Loss: 0.0035
# Epoch [41/45], Average Training Loss: 0.0164
# Epoch [41/45], Average Validation Loss: 0.0349
# Epoch [42/45], Step [0/378], Loss: 0.0004
# Epoch [42/45], Step [100/378], Loss: 0.0012
# Epoch [42/45], Step [200/378], Loss: 0.0010
# Epoch [42/45], Step [300/378], Loss: 0.0082
# Epoch [42/45], Average Training Loss: 0.0151
# Epoch [42/45], Average Validation Loss: 0.0334
# Epoch [43/45], Step [0/378], Loss: 0.0094
# Epoch [43/45], Step [100/378], Loss: 0.0014
# Epoch [43/45], Step [200/378], Loss: 0.0006
# Epoch [43/45], Step [300/378], Loss: 0.0010
# Epoch [43/45], Average Training Loss: 0.0160
# Epoch [43/45], Average Validation Loss: 0.0329
# Epoch [44/45], Step [0/378], Loss: 0.0004
# Epoch [44/45], Step [100/378], Loss: 0.0053
# Epoch [44/45], Step [200/378], Loss: 0.0099
# Epoch [44/45], Step [300/378], Loss: 0.0029
# Epoch [44/45], Average Training Loss: 0.0142
# Epoch [44/45], Average Validation Loss: 0.0414
# Epoch [45/45], Step [0/378], Loss: 0.0116
# Epoch [45/45], Step [100/378], Loss: 0.0292
# Epoch [45/45], Step [200/378], Loss: 0.0585
# Epoch [45/45], Step [300/378], Loss: 0.0009
# Epoch [45/45], Average Training Loss: 0.0167
# Epoch [45/45], Average Validation Loss: 0.0367
# Training complete.
# Run 2 Test Accuracy: 99.07%
# Epoch [1/45], Step [0/378], Loss: 2.5340
# Epoch [1/45], Step [100/378], Loss: 2.2057
# Epoch [1/45], Step [200/378], Loss: 2.5498
# Epoch [1/45], Step [300/378], Loss: 2.4551
# Epoch [1/45], Average Training Loss: 2.3534
# Epoch [1/45], Average Validation Loss: 2.3465
# Epoch [2/45], Step [0/378], Loss: 2.2799
# Epoch [2/45], Step [100/378], Loss: 2.2914
# Epoch [2/45], Step [200/378], Loss: 2.2932
# Epoch [2/45], Step [300/378], Loss: 2.1541
# Epoch [2/45], Average Training Loss: 2.3152
# Epoch [2/45], Average Validation Loss: 2.2607
# Epoch [3/45], Step [0/378], Loss: 2.2074
# Epoch [3/45], Step [100/378], Loss: 2.1643
# Epoch [3/45], Step [200/378], Loss: 2.2017
# Epoch [3/45], Step [300/378], Loss: 1.9213
# Epoch [3/45], Average Training Loss: 2.1188
# Epoch [3/45], Average Validation Loss: 1.8467
# Epoch [4/45], Step [0/378], Loss: 1.9694
# Epoch [4/45], Step [100/378], Loss: 1.4760
# Epoch [4/45], Step [200/378], Loss: 1.5937
# Epoch [4/45], Step [300/378], Loss: 1.1874
# Epoch [4/45], Average Training Loss: 1.4762
# Epoch [4/45], Average Validation Loss: 1.0621
# Epoch [5/45], Step [0/378], Loss: 0.9308
# Epoch [5/45], Step [100/378], Loss: 0.8332
# Epoch [5/45], Step [200/378], Loss: 0.9460
# Epoch [5/45], Step [300/378], Loss: 0.6268
# Epoch [5/45], Average Training Loss: 0.9005
# Epoch [5/45], Average Validation Loss: 0.6734
# Epoch [6/45], Step [0/378], Loss: 0.7943
# Epoch [6/45], Step [100/378], Loss: 0.4650
# Epoch [6/45], Step [200/378], Loss: 0.6553
# Epoch [6/45], Step [300/378], Loss: 0.3549
# Epoch [6/45], Average Training Loss: 0.5514
# Epoch [6/45], Average Validation Loss: 0.3925
# Epoch [7/45], Step [0/378], Loss: 0.4154
# Epoch [7/45], Step [100/378], Loss: 0.1659
# Epoch [7/45], Step [200/378], Loss: 0.2994
# Epoch [7/45], Step [300/378], Loss: 0.3993
# Epoch [7/45], Average Training Loss: 0.3546
# Epoch [7/45], Average Validation Loss: 0.2453
# Epoch [8/45], Step [0/378], Loss: 0.3946
# Epoch [8/45], Step [100/378], Loss: 0.2610
# Epoch [8/45], Step [200/378], Loss: 0.1658
# Epoch [8/45], Step [300/378], Loss: 0.2627
# Epoch [8/45], Average Training Loss: 0.2472
# Epoch [8/45], Average Validation Loss: 0.1454
# Epoch [9/45], Step [0/378], Loss: 0.1839
# Epoch [9/45], Step [100/378], Loss: 0.2512
# Epoch [9/45], Step [200/378], Loss: 0.2049
# Epoch [9/45], Step [300/378], Loss: 0.2097
# Epoch [9/45], Average Training Loss: 0.1869
# Epoch [9/45], Average Validation Loss: 0.1277
# Epoch [10/45], Step [0/378], Loss: 0.1480
# Epoch [10/45], Step [100/378], Loss: 0.1363
# Epoch [10/45], Step [200/378], Loss: 0.1873
# Epoch [10/45], Step [300/378], Loss: 0.0890
# Epoch [10/45], Average Training Loss: 0.1368
# Epoch [10/45], Average Validation Loss: 0.1409
# Epoch [11/45], Step [0/378], Loss: 0.1370
# Epoch [11/45], Step [100/378], Loss: 0.0616
# Epoch [11/45], Step [200/378], Loss: 0.1025
# Epoch [11/45], Step [300/378], Loss: 0.0327
# Epoch [11/45], Average Training Loss: 0.1130
# Epoch [11/45], Average Validation Loss: 0.0832
# Epoch [12/45], Step [0/378], Loss: 0.0431
# Epoch [12/45], Step [100/378], Loss: 0.0539
# Epoch [12/45], Step [200/378], Loss: 0.0785
# Epoch [12/45], Step [300/378], Loss: 0.0162
# Epoch [12/45], Average Training Loss: 0.0940
# Epoch [12/45], Average Validation Loss: 0.0856
# Epoch [13/45], Step [0/378], Loss: 0.0280
# Epoch [13/45], Step [100/378], Loss: 0.2887
# Epoch [13/45], Step [200/378], Loss: 0.0056
# Epoch [13/45], Step [300/378], Loss: 0.1507
# Epoch [13/45], Average Training Loss: 0.0836
# Epoch [13/45], Average Validation Loss: 0.0815
# Epoch [14/45], Step [0/378], Loss: 0.0971
# Epoch [14/45], Step [100/378], Loss: 0.0190
# Epoch [14/45], Step [200/378], Loss: 0.0207
# Epoch [14/45], Step [300/378], Loss: 0.0138
# Epoch [14/45], Average Training Loss: 0.0720
# Epoch [14/45], Average Validation Loss: 0.0649
# Epoch [15/45], Step [0/378], Loss: 0.0669
# Epoch [15/45], Step [100/378], Loss: 0.0269
# Epoch [15/45], Step [200/378], Loss: 0.0938
# Epoch [15/45], Step [300/378], Loss: 0.0261
# Epoch [15/45], Average Training Loss: 0.0613
# Epoch [15/45], Average Validation Loss: 0.0681
# Epoch [16/45], Step [0/378], Loss: 0.0947
# Epoch [16/45], Step [100/378], Loss: 0.0360
# Epoch [16/45], Step [200/378], Loss: 0.0145
# Epoch [16/45], Step [300/378], Loss: 0.0186
# Epoch [16/45], Average Training Loss: 0.0528
# Epoch [16/45], Average Validation Loss: 0.0485
# Epoch [17/45], Step [0/378], Loss: 0.0399
# Epoch [17/45], Step [100/378], Loss: 0.0035
# Epoch [17/45], Step [200/378], Loss: 0.0571
# Epoch [17/45], Step [300/378], Loss: 0.0609
# Epoch [17/45], Average Training Loss: 0.0509
# Epoch [17/45], Average Validation Loss: 0.0529
# Epoch [18/45], Step [0/378], Loss: 0.0537
# Epoch [18/45], Step [100/378], Loss: 0.0210
# Epoch [18/45], Step [200/378], Loss: 0.0615
# Epoch [18/45], Step [300/378], Loss: 0.0653
# Epoch [18/45], Average Training Loss: 0.0453
# Epoch [18/45], Average Validation Loss: 0.0448
# Epoch [19/45], Step [0/378], Loss: 0.0494
# Epoch [19/45], Step [100/378], Loss: 0.0995
# Epoch [19/45], Step [200/378], Loss: 0.0399
# Epoch [19/45], Step [300/378], Loss: 0.1071
# Epoch [19/45], Average Training Loss: 0.0402
# Epoch [19/45], Average Validation Loss: 0.0544
# Epoch [20/45], Step [0/378], Loss: 0.0669
# Epoch [20/45], Step [100/378], Loss: 0.0034
# Epoch [20/45], Step [200/378], Loss: 0.0750
# Epoch [20/45], Step [300/378], Loss: 0.0061
# Epoch [20/45], Average Training Loss: 0.0398
# Epoch [20/45], Average Validation Loss: 0.0638
# Epoch [21/45], Step [0/378], Loss: 0.0022
# Epoch [21/45], Step [100/378], Loss: 0.0105
# Epoch [21/45], Step [200/378], Loss: 0.0063
# Epoch [21/45], Step [300/378], Loss: 0.0225
# Epoch [21/45], Average Training Loss: 0.0396
# Epoch [21/45], Average Validation Loss: 0.0425
# Epoch [22/45], Step [0/378], Loss: 0.0251
# Epoch [22/45], Step [100/378], Loss: 0.0081
# Epoch [22/45], Step [200/378], Loss: 0.0424
# Epoch [22/45], Step [300/378], Loss: 0.0114
# Epoch [22/45], Average Training Loss: 0.0330
# Epoch [22/45], Average Validation Loss: 0.0460
# Epoch [23/45], Step [0/378], Loss: 0.0682
# Epoch [23/45], Step [100/378], Loss: 0.0053
# Epoch [23/45], Step [200/378], Loss: 0.1706
# Epoch [23/45], Step [300/378], Loss: 0.0080
# Epoch [23/45], Average Training Loss: 0.0340
# Epoch [23/45], Average Validation Loss: 0.0415
# Epoch [24/45], Step [0/378], Loss: 0.0305
# Epoch [24/45], Step [100/378], Loss: 0.0644
# Epoch [24/45], Step [200/378], Loss: 0.0131
# Epoch [24/45], Step [300/378], Loss: 0.0033
# Epoch [24/45], Average Training Loss: 0.0318
# Epoch [24/45], Average Validation Loss: 0.0416
# Epoch [25/45], Step [0/378], Loss: 0.0124
# Epoch [25/45], Step [100/378], Loss: 0.0199
# Epoch [25/45], Step [200/378], Loss: 0.0009
# Epoch [25/45], Step [300/378], Loss: 0.0010
# Epoch [25/45], Average Training Loss: 0.0279
# Epoch [25/45], Average Validation Loss: 0.0387
# Epoch [26/45], Step [0/378], Loss: 0.0110
# Epoch [26/45], Step [100/378], Loss: 0.0143
# Epoch [26/45], Step [200/378], Loss: 0.0089
# Epoch [26/45], Step [300/378], Loss: 0.0057
# Epoch [26/45], Average Training Loss: 0.0268
# Epoch [26/45], Average Validation Loss: 0.0384
# Epoch [27/45], Step [0/378], Loss: 0.0513
# Epoch [27/45], Step [100/378], Loss: 0.0025
# Epoch [27/45], Step [200/378], Loss: 0.0094
# Epoch [27/45], Step [300/378], Loss: 0.0089
# Epoch [27/45], Average Training Loss: 0.0278
# Epoch [27/45], Average Validation Loss: 0.0365
# Epoch [28/45], Step [0/378], Loss: 0.0374
# Epoch [28/45], Step [100/378], Loss: 0.0070
# Epoch [28/45], Step [200/378], Loss: 0.0094
# Epoch [28/45], Step [300/378], Loss: 0.0037
# Epoch [28/45], Average Training Loss: 0.0274
# Epoch [28/45], Average Validation Loss: 0.0427
# Epoch [29/45], Step [0/378], Loss: 0.0036
# Epoch [29/45], Step [100/378], Loss: 0.0170
# Epoch [29/45], Step [200/378], Loss: 0.0074
# Epoch [29/45], Step [300/378], Loss: 0.1927
# Epoch [29/45], Average Training Loss: 0.0263
# Epoch [29/45], Average Validation Loss: 0.0409
# Epoch [30/45], Step [0/378], Loss: 0.0069
# Epoch [30/45], Step [100/378], Loss: 0.0098
# Epoch [30/45], Step [200/378], Loss: 0.0052
# Epoch [30/45], Step [300/378], Loss: 0.0154
# Epoch [30/45], Average Training Loss: 0.0230
# Epoch [30/45], Average Validation Loss: 0.0331
# Epoch [31/45], Step [0/378], Loss: 0.0034
# Epoch [31/45], Step [100/378], Loss: 0.0073
# Epoch [31/45], Step [200/378], Loss: 0.1910
# Epoch [31/45], Step [300/378], Loss: 0.0508
# Epoch [31/45], Average Training Loss: 0.0265
# Epoch [31/45], Average Validation Loss: 0.0428
# Epoch [32/45], Step [0/378], Loss: 0.0037
# Epoch [32/45], Step [100/378], Loss: 0.0081
# Epoch [32/45], Step [200/378], Loss: 0.0592
# Epoch [32/45], Step [300/378], Loss: 0.0095
# Epoch [32/45], Average Training Loss: 0.0238
# Epoch [32/45], Average Validation Loss: 0.0358
# Epoch [33/45], Step [0/378], Loss: 0.0096
# Epoch [33/45], Step [100/378], Loss: 0.0054
# Epoch [33/45], Step [200/378], Loss: 0.0121
# Epoch [33/45], Step [300/378], Loss: 0.0027
# Epoch [33/45], Average Training Loss: 0.0233
# Epoch [33/45], Average Validation Loss: 0.0387
# Epoch [34/45], Step [0/378], Loss: 0.0019
# Epoch [34/45], Step [100/378], Loss: 0.0072
# Epoch [34/45], Step [200/378], Loss: 0.0067
# Epoch [34/45], Step [300/378], Loss: 0.0185
# Epoch [34/45], Average Training Loss: 0.0202
# Epoch [34/45], Average Validation Loss: 0.0455
# Epoch [35/45], Step [0/378], Loss: 0.0708
# Epoch [35/45], Step [100/378], Loss: 0.0011
# Epoch [35/45], Step [200/378], Loss: 0.0028
# Epoch [35/45], Step [300/378], Loss: 0.0012
# Epoch [35/45], Average Training Loss: 0.0209
# Epoch [35/45], Average Validation Loss: 0.0340
# Epoch [36/45], Step [0/378], Loss: 0.0002
# Epoch [36/45], Step [100/378], Loss: 0.0132
# Epoch [36/45], Step [200/378], Loss: 0.0002
# Epoch [36/45], Step [300/378], Loss: 0.0014
# Epoch [36/45], Average Training Loss: 0.0173
# Epoch [36/45], Average Validation Loss: 0.0374
# Epoch [37/45], Step [0/378], Loss: 0.0099
# Epoch [37/45], Step [100/378], Loss: 0.0034
# Epoch [37/45], Step [200/378], Loss: 0.0011
# Epoch [37/45], Step [300/378], Loss: 0.0071
# Epoch [37/45], Average Training Loss: 0.0186
# Epoch [37/45], Average Validation Loss: 0.0359
# Epoch [38/45], Step [0/378], Loss: 0.0234
# Epoch [38/45], Step [100/378], Loss: 0.0009
# Epoch [38/45], Step [200/378], Loss: 0.0057
# Epoch [38/45], Step [300/378], Loss: 0.0028
# Epoch [38/45], Average Training Loss: 0.0181
# Epoch [38/45], Average Validation Loss: 0.0367
# Epoch [39/45], Step [0/378], Loss: 0.0479
# Epoch [39/45], Step [100/378], Loss: 0.0002
# Epoch [39/45], Step [200/378], Loss: 0.0028
# Epoch [39/45], Step [300/378], Loss: 0.0006
# Epoch [39/45], Average Training Loss: 0.0173
# Epoch [39/45], Average Validation Loss: 0.0376
# Epoch [40/45], Step [0/378], Loss: 0.0091
# Epoch [40/45], Step [100/378], Loss: 0.0182
# Epoch [40/45], Step [200/378], Loss: 0.0078
# Epoch [40/45], Step [300/378], Loss: 0.0109
# Epoch [40/45], Average Training Loss: 0.0180
# Epoch [40/45], Average Validation Loss: 0.0310
# Epoch [41/45], Step [0/378], Loss: 0.0022
# Epoch [41/45], Step [100/378], Loss: 0.0897
# Epoch [41/45], Step [200/378], Loss: 0.0018
# Epoch [41/45], Step [300/378], Loss: 0.0036
# Epoch [41/45], Average Training Loss: 0.0170
# Epoch [41/45], Average Validation Loss: 0.0366
# Epoch [42/45], Step [0/378], Loss: 0.0110
# Epoch [42/45], Step [100/378], Loss: 0.0014
# Epoch [42/45], Step [200/378], Loss: 0.0829
# Epoch [42/45], Step [300/378], Loss: 0.0585
# Epoch [42/45], Average Training Loss: 0.0178
# Epoch [42/45], Average Validation Loss: 0.0347
# Epoch [43/45], Step [0/378], Loss: 0.0181
# Epoch [43/45], Step [100/378], Loss: 0.0015
# Epoch [43/45], Step [200/378], Loss: 0.0040
# Epoch [43/45], Step [300/378], Loss: 0.0242
# Epoch [43/45], Average Training Loss: 0.0162
# Epoch [43/45], Average Validation Loss: 0.0383
# Epoch [44/45], Step [0/378], Loss: 0.0012
# Epoch [44/45], Step [100/378], Loss: 0.0033
# Epoch [44/45], Step [200/378], Loss: 0.0940
# Epoch [44/45], Step [300/378], Loss: 0.0010
# Epoch [44/45], Average Training Loss: 0.0167
# Epoch [44/45], Average Validation Loss: 0.0353
# Epoch [45/45], Step [0/378], Loss: 0.0136
# Epoch [45/45], Step [100/378], Loss: 0.0012
# Epoch [45/45], Step [200/378], Loss: 0.0948
# Epoch [45/45], Step [300/378], Loss: 0.0074
# Epoch [45/45], Average Training Loss: 0.0163
# Epoch [45/45], Average Validation Loss: 0.0336
# Training complete.
# Run 3 Test Accuracy: 99.04%
# Average Test Accuracy over 3 runs: 99.07%

# %%
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(int(cm[i, j]), 'd'),
                horizontalalignment="center",
                color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    
confusion_matrix = np.zeros((num_classes, num_classes))
with torch.no_grad():
    for data, targets in test_loader:
        data, targets = data.to(device), targets.to(device)
        _, _, outputs = model(data)
        _, predicted = outputs.max(1)
        for t, p in zip(targets.view(-1), predicted.view(-1)):
            confusion_matrix[t.long(), p.long()] += 1

plot_confusion_matrix(confusion_matrix, list(range(num_classes)))

# %%
for batch_idx, (data, targets) in enumerate(train_loader):
    data, targets = data.to(device), targets.to(device)

x1, x2, outputs = model(data)


feature_maps = x1[1].detach().cpu().numpy()  


for i, feature_map in enumerate(feature_maps):
    plt.subplot(8, 8, i+1)
    plt.imshow(feature_map, cmap='viridis')
    plt.axis('off')

plt.show()

# %%
feature_maps = x2[1].detach().cpu().numpy()  


for i, feature_map in enumerate(feature_maps):
    plt.subplot(8, 16, i+1)
    plt.imshow(feature_map, cmap='viridis')
    plt.axis('off')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from torchvision import utils

model = SimpleCNN_x()

def visTensor(tensor, ch=0, nrow=8, padding=1): 
 
        tensor = tensor[:,ch,:,:].unsqueeze(dim=1)

        rows = np.min((tensor.shape[0] // nrow + 1, 64))    
        grid = utils.make_grid(tensor, nrow=nrow, normalize=True, padding=padding)
        plt.figure( figsize=(nrow,rows) )
        plt.imshow(grid.numpy().transpose((1, 2, 0)))

filter = model.conv1.weight.data.clone()
visTensor(filter, ch=0)

plt.axis('off')
plt.ioff()
plt.show()

# %%
filter = model.conv2.weight.data.clone()
visTensor(filter, ch=0)

plt.axis('off')
plt.ioff()
plt.show()

# %%
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# model = SimpleCNN_x().to(device)
# criterion = nn.CrossEntropyLoss()  
# optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.8)

# num_epochs = 30

# loss_values = []


# for epoch in range(num_epochs):
#     model.train()
#     epoch_loss = 0.0
#     for batch_idx, (data, targets) in enumerate(train_loader):
#         data, targets = data.to(device), targets.to(device)

       
#         _, _, outputs = model(data)
#         loss = criterion(outputs, targets)
#         epoch_loss += loss.item()

     
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()

#         if batch_idx % 100 == 0:  
#             print(f'Epoch [{epoch+1}/{num_epochs}], Step [{batch_idx}/{len(train_loader)}], Loss: {loss.item():.4f}')

#         torch.cuda.empty_cache()
#     avg_epoch_loss = epoch_loss / len(train_loader)
#     loss_values.append(avg_epoch_loss)
#     print(f'Epoch [{epoch+1}/{num_epochs}], Average Loss: {avg_epoch_loss:.4f}')

# # Plot the loss values
# plt.plot(loss_values)
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.title('Training Loss vs. Epoch')
# plt.show()

# print("Training complete.")

# %%
train_transforms = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor()  
])
test_dataset = datasets.ImageFolder(os.path.dirname('C:/Users/denis/Desktop/HNS/projekt1/Dataset_Znacky/test-no-labels/'), transform = train_transforms)

test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
import matplotlib.pyplot as plt

c_names = ['1','2','12','13','14','15','17','23','25','26','28','33']

def test_images(model, device, image_tensors, class_names):

    assert image_tensors.size(0) == 10
    
    
    model.eval()
    image_tensors = image_tensors.to(device)
    
    with torch.no_grad():
        _, _, outputs = model(image_tensors)
        _, predicted_indices = outputs.max(1)  

    plt.figure(figsize=(20, 10))
    for i in range(10):
        plt.subplot(2, 5, i + 1)
        predicted_class = class_names[predicted_indices[i].item()]
        
    
        np_image = image_tensors[i].cpu().numpy().transpose((1, 2, 0))
        plt.imshow(np_image)
        plt.title(f"Predicted: {predicted_class}")
        plt.axis('off')  

    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
def display_predictions(dataset, model, num_images=25, num_columns=5):
   
    num_rows = int(num_images / num_columns) + (num_images % num_columns > 0)
    
    plt.figure(figsize=(15, 5*num_rows))
    for i in range(num_images):
        image, true_label = dataset[i]
        
    
        input_tensor = image.unsqueeze(0).to(device)
       
    
        with torch.no_grad():
            outputs = model(input_tensor)
            _, predicted_label = torch.max(outputs[2], 1)
        
        if isinstance(image, torch.Tensor):
            image = transforms.ToPILImage()(image)
        
        plt.subplot(num_rows, num_columns, i+1)
        plt.imshow(image)
        plt.title(f"True: {dataset.classes[true_label]}\nPredicted: {dataset.classes[predicted_label.item()]}")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

display_predictions(test_dataset, model, num_images=12*5)
