# %%
import torch
from torch import nn
from torchvision import datasets
from torchvision.transforms import ToTensor
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
torch.cuda.empty_cache()
# Out:
# Using cuda device

# %%
mat = scipy.io.loadmat('DynCislaData_Python.mat')
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'XTest', 'XTrain', 'YTest', 'YTrain'])

# %%
xtrain = mat['XTrain']
ytrain = mat['YTrain']
XTest = mat['XTest']
YTest = mat['YTest']
print(type(xtrain))
print(len(xtrain))
print(type(XTest))
print(len(XTest))
# Out:
# <class 'numpy.ndarray'>
# 200
# <class 'numpy.ndarray'>
# 98

# %%
print(type(ytrain))
print(len(ytrain))
ytrain.shape
# Out:
# <class 'numpy.ndarray'>
# 200
# (200, 1)

# %%
ytrain
# Out:
# array([[ 2],
#        [ 2],
#        [ 2],
#        [ 2],
#        [ 2],
#        [ 2],
#        [ 2],
#        [ 8],
#        [ 2],
#        [ 4],
#        [ 5],
#        [ 1],
#        [ 2],
#        [ 7],
#        [ 7],
#        [ 1],
#        [ 8],
#        [ 5],
#        [ 5],
#        [ 3],
#        [ 5],
#        [ 7],
#        [ 7],
#        [ 1],
#        [ 1],
#        [ 8],
#        [ 7],
#        [ 7],
#        [ 7],
#        [ 8],
#        [ 1],
#        [ 2],
#        [ 3],
#        [ 5],
#        [ 7],
#        [ 1],
#        [ 2],
#        [ 2],
#        [ 3],
#        [ 3],
#        [ 4],
#        [ 7],
#        [ 7],
#        [ 8],
#        [ 5],
#        [ 8],
#        [ 8],
#        [ 1],
#        [ 2],
#        [ 4],
#        [ 4],
#        [ 7],
#        [ 1],
#        [ 1],
#        [ 3],
#        [ 3],
#        [ 4],
#        [ 4],
#        [ 5],
#        [ 7],
#        [10],
#        [ 1],
#        [ 2],
#        [ 8],
#        [ 8],
#        [ 3],
#        [ 8],
#        [ 8],
#        [ 2],
#        [ 3],
#        [ 3],
#        [ 4],
#        [ 4],
#        [ 4],
#        [ 5],
#        [ 8],
#        [ 5],
#        [ 5],
#        [ 7],
#        [ 7],
#        [ 2],
#        [ 3],
#        [ 7],
#        [ 8],
#        [ 1],
#        [ 1],
#        [ 2],
#        [ 3],
#        [ 4],
#        [ 5],
#        [ 4],
#        [ 7],
#        [ 8],
#        [ 1],
#        [ 1],
#        [ 5],
#        [ 3],
#        [ 3],
#        [ 6],
#        [ 9],
#        [10],
#        [ 1],
#        [ 5],
#        [ 2],
#        [ 4],
#        [ 5],
#        [ 8],
#        [ 9],
#        [10],
#        [ 1],
#        [ 3],
#        [ 7],
#        [ 8],
#        [ 3],
#        [ 4],
#        [ 8],
#        [ 1],
#        [ 3],
#        [ 7],
#        [10],
#        [ 6],
#        [ 6],
#        [ 6],
#        [ 7],
#        [ 5],
#        [ 8],
#        [ 9],
#        [ 9],
#        [ 3],
#        [ 6],
#        [ 9],
#        [10],
#        [ 5],
#        [ 9],
#        [ 9],
#        [10],
#        [ 1],
#        [ 3],
#        [ 5],
#        [ 6],
#        [ 1],
#        [ 4],
#        [ 4],
#        [ 5],
#        [ 5],
#        [ 9],
#        [10],
#        [ 3],
#        [10],
#        [ 6],
#        [ 9],
#        [10],
#        [10],
#        [ 9],
#        [10],
#        [10],
#        [10],
#        [ 4],
#        [ 1],
#        [ 6],
#        [10],
#        [ 4],
#        [ 4],
#        [ 6],
#        [10],
#        [ 9],
#        [10],
#        [ 6],
#        [ 6],
#        [ 4],
#        [ 9],
#        [ 6],
#        [10],
#        [ 2],
#        [ 6],
#        [10],
#        [ 8],
#        [10],
#        [ 9],
#        [ 9],
#        [ 6],
#        [ 9],
#        [ 6],
#        [ 9],
#        [ 9],
#        [ 6],
#        [ 9],
#        [ 9],
#        [ 6],
#        [ 8],
#        [ 6],
#        [ 6],
#        [ 4],
#        [ 2],
#        [ 3],
#        [ 7],
#        [ 6],
#        [ 9],
#        [10],
#        [ 5]], dtype=uint8)

# %%
xtrain.shape
# Out:
# (200, 1)

# %%
xtrain[20][0][:][:]
# Out:
# array([[103, 104, 106, 101,  96,  88,  76,  62,  47,  36,  23,  13,   5,
#           1,   0,   1,   5,  12,  26,  42,  63,  84, 103, 119, 131, 142,
#         147, 150, 154, 153, 149, 140, 131, 115, 109, 110, 110],
#        [371, 371, 371, 368, 362, 352, 338, 322, 300, 289, 269, 254, 242,
#         230, 221, 213, 204, 198, 193, 189, 193, 193, 194, 194, 195, 196,
#         193, 190, 184, 172, 153, 130, 103,  70,  38,  15,   0]],
#       dtype=uint16)

# %%
xtrain[80][0][:][:]
# Out:
# array([[ 66,  66,  66,  67,  66,  67,  66,  66,  66,  65,  66,  64,  65,
#          65,  66,  66,  68,  68,  68,  70,  71,  72,  73,  74,  79,  80,
#          81,  82,  82,  81,  79,  76,  72,  67,  61,  55,  47,  40,  31,
#          24,  17,  12,   7,   3,   1,   0],
#        [  0,   1,   2,   3,   3,   3,   3,   5,   7,  11,  17,  25,  38,
#          54,  70,  88, 109, 135, 152, 170, 187, 201, 213, 224, 248, 252,
#         256, 259, 260, 260, 258, 254, 248, 242, 233, 223, 212, 200, 181,
#         169, 159, 153, 148, 143, 136, 134]], dtype=uint16)

# %%
plt.plot(xtrain[100][0][0][:], xtrain[100][0][1][:])
plt.axis('on')
plt.show()

# %%
fig, axs = plt.subplots(2)
axs[0].plot(xtrain[100][0][0][:],)
axs[0].set_title('Y')
axs[1].plot(xtrain[100][0][1][:], 'tab:red')
axs[1].set_title('X')

plt.axis('on')
plt.show()

# %%
# x = []
# y = []

# for num in range(200):
#     x.append(xtrain[num][0][1][:].astype(int))
#     y.append(xtrain[num][0][0][:].astype(int))


# x_test = []
# y_test = []
# for num in range(98):
#     x_test.append(XTest[num][0][1][:].astype(int))
#     x_test.append(XTest[num][0][0][:].astype(int))

# %%
# x = []
# y = []
# max_length = 0  # Variable to keep track of the longest sequence

# for num in range(200):
#     x_sequence = xtrain[num][0][1][:].astype(int)
#     y_sequence = xtrain[num][0][0][:].astype(int)
    
#     # Append the sequences to the lists
#     x.append(x_sequence)
#     y.append(y_sequence)

#     # Update max_length if a longer sequence is found
#     max_length = max(max_length, len(x_sequence), len(y_sequence))

# x_test = []
# y_test = []

# for num in range(98):
#     x_test_sequence = XTest[num][0][1][:].astype(int)
#     y_test_sequence = XTest[num][0][0][:].astype(int)
    
#     # Append the sequences to the test lists
#     x_test.append(x_test_sequence)
#     y_test.append(y_test_sequence)

#     # Update max_length for test data as well
#     max_length = max(max_length, len(x_test_sequence), len(y_test_sequence))

# # Now max_length holds the length of the longest sequence
# print("Longest sequence length:", max_length)

# %%
train_label = []
test_label = []

for num in range(200):
    train_label.append((ytrain[num][0].astype(int)) - 1)


for num in range(98):
    test_label.append((YTest[num][0].astype(int)) - 1)

# %%
import numpy as np

# Assuming xtrain and XTest are your training and testing datasets
x = []
y = []
x_sin_all = []
y_sin_all =[]
minn = 1
max_length = 163  # The longest sequence length determined earlier


def pad_sequence(seq, max_len):
    """ Pads the sequence to the max_len with zeros. """
   
    padding_length = max_len - len(seq)
    return np.pad(seq, (0, padding_length), mode='constant')

for num in range(200):
    x_sequence = xtrain[num][0][1][:].astype(int)
    y_sequence = xtrain[num][0][0][:].astype(int)

    
    x_sequence_padded = pad_sequence(x_sequence, max_length)
    y_sequence_padded = pad_sequence(y_sequence, max_length)
    minn = max(max_length, len(y_sequence_padded), len(x_sequence_padded))
    # Append the padded sequences to the lists
    x_sin = np.sin(x_sequence_padded)
    y_sin = np.sin(y_sequence_padded)

    x_sin_all.append(x_sin)
    y_sin_all.append(y_sin)
    x.append(x_sequence_padded)
    y.append(y_sequence_padded)

x_test = []
y_test = []
x_test_sin_all = []
y_test_sin_all = []

for num in range(98):
    
    x_test_sequence = XTest[num][0][1][:].astype(int)
    y_test_sequence = XTest[num][0][0][:].astype(int)
    
 
    # Pad the sequences
    x_test_sequence_padded = pad_sequence(x_test_sequence, max_length)
    y_test_sequence_padded = pad_sequence(y_test_sequence, max_length)
    minn = max(max_length, len(x_test_sequence_padded), len(y_test_sequence_padded))
    x_test_sin = np.sin(x_test_sequence_padded)
    y_test_sin = np.sin(y_test_sequence_padded)
    # Append the padded sequences to the test lists

    x_test_sin_all.append(x_test_sin)
    y_test_sin_all.append(y_test_sin)
    x_test.append(x_test_sequence_padded)
    y_test.append(y_test_sequence_padded)

paired_train_data = list(zip(x, y, x_sin_all, y_sin_all))
paired_test_data = list(zip(x_test, y_test, x_test_sin_all, y_test_sin_all))
print("shortest sequence length:", minn)
# Out:
# shortest sequence length: 163

# %%
print(len(paired_train_data))
print(type(y[1]))
print(type(train_label[1]))
# Out:
# 200
# <class 'numpy.ndarray'>
# <class 'numpy.int32'>

# %%
class CustomDataset(Dataset):
    def __init__(self, sequences, labels):
        self.sequences = sequences
        self.labels = labels
        
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        # Assuming each sequence is a 1D array and needs to be reshaped
        sequence = torch.tensor(self.sequences[idx], dtype=torch.float32).view(-1, 4)
        label = torch.tensor(self.labels[idx], dtype=torch.long)  # Assuming labels are integers
        
        return sequence, label

# %%
dataset = CustomDataset(paired_train_data, train_label)
dataset_test = CustomDataset(paired_test_data, test_label)

# %%
train_loader = DataLoader(dataset, batch_size=8, shuffle=True)
test_loader = DataLoader(dataset_test, batch_size=8, shuffle=False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class DualInputLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes=10):
        super(DualInputLSTM, self).__init__()
        
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.lstm1 = nn.LSTM(input_size, hidden_size, num_layers, dropout=0.2, batch_first=True)
        self.fc2 = nn.Linear(hidden_size, num_classes)

    def forward(self, x):

        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)

        out, _ = self.lstm1(x, (h0, c0))
        out = out[:, -1, :]  

        out = self.fc2(out)
        return out

# Creating the model instance

# %%
import torch
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torch.nn import CrossEntropyLoss
from torch.optim import Adam

# Assuming DualInputLSTM and your datasets are correctly defined

best_accuracy = 0.0

# Training and Validation loop
num_epochs = 200
for run in range(4):

    print(f"Starting Run {run+1}")
    model = DualInputLSTM(4, 128, 3)
    criterion = CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=0.001)

    train_loss_values = []
    val_loss_values = []

    for epoch in range(num_epochs):
        model.train()
        total_train_loss = 0.0

        for x1, labels in train_loader:
            optimizer.zero_grad()
            outputs = model(x1)
            loss = criterion(outputs, labels.long())
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()
        
        avg_train_loss = total_train_loss / len(train_loader)
        train_loss_values.append(avg_train_loss)

        # Validation phase
        model.eval()
        total_val_loss = 0.0
        correct = 0
        total = 0
        with torch.no_grad():
            for x1, labels in test_loader:
                outputs = model(x1)
                loss = criterion(outputs, labels.long())
                total_val_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        
        avg_val_loss = total_val_loss / len(test_loader)
        val_loss_values.append(avg_val_loss)
        accuracy = 100 * correct / total

        print(f"Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, Validation Loss: {avg_val_loss:.4f}, Accuracy: {accuracy:.2f}%")

        # Save the model with the highest accuracy after 30 epochs
        if epoch >= 40 and accuracy > best_accuracy:
            best_accuracy = accuracy
 
            torch.save(model.state_dict(), 'best_model.pth')
            

# Plotting the training and validation loss
    plt.figure(figsize=(10, 5))
    plt.plot(train_loss_values, label='Training Loss')
    plt.plot(val_loss_values, label='Validation Loss')
    plt.title("Training and Validation Loss Per Epoch")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.show()

    print(f"Best Test acc: {best_accuracy}")
# Out:
# Starting Run 1
# C:\Users\denis\AppData\Local\Temp\ipykernel_20532\4002005459.py:11: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:248.)
#   sequence = torch.tensor(self.sequences[idx], dtype=torch.float32).view(-1, 4)
# Epoch [1/200], Training Loss: 2.3105, Validation Loss: 2.3100, Accuracy: 7.14%
# Epoch [2/200], Training Loss: 2.3078, Validation Loss: 2.3094, Accuracy: 7.14%
# Epoch [3/200], Training Loss: 2.3057, Validation Loss: 2.3074, Accuracy: 7.14%
# Epoch [4/200], Training Loss: 2.3050, Validation Loss: 2.3074, Accuracy: 7.14%
# Epoch [5/200], Training Loss: 2.3064, Validation Loss: 2.3071, Accuracy: 7.14%
# Epoch [6/200], Training Loss: 2.3055, Validation Loss: 2.3066, Accuracy: 7.14%
# Epoch [7/200], Training Loss: 2.3051, Validation Loss: 2.3060, Accuracy: 7.14%
# Epoch [8/200], Training Loss: 2.3047, Validation Loss: 2.3080, Accuracy: 7.14%
# Epoch [9/200], Training Loss: 2.3046, Validation Loss: 2.3057, Accuracy: 7.14%
# Epoch [10/200], Training Loss: 2.3041, Validation Loss: 2.3060, Accuracy: 7.14%
# Epoch [11/200], Training Loss: 2.3055, Validation Loss: 2.3047, Accuracy: 9.18%
# Epoch [12/200], Training Loss: 2.3047, Validation Loss: 2.3067, Accuracy: 7.14%
# Epoch [13/200], Training Loss: 2.3041, Validation Loss: 2.3062, Accuracy: 7.14%
# Epoch [14/200], Training Loss: 2.3060, Validation Loss: 2.3040, Accuracy: 9.18%
# Epoch [15/200], Training Loss: 2.3041, Validation Loss: 2.3076, Accuracy: 7.14%
# Epoch [16/200], Training Loss: 2.3040, Validation Loss: 2.3062, Accuracy: 9.18%
# Epoch [17/200], Training Loss: 2.3036, Validation Loss: 2.3059, Accuracy: 7.14%
# Epoch [18/200], Training Loss: 2.3029, Validation Loss: 2.3031, Accuracy: 6.12%
# Epoch [19/200], Training Loss: 2.3071, Validation Loss: 2.3043, Accuracy: 7.14%
# Epoch [20/200], Training Loss: 2.2984, Validation Loss: 2.3038, Accuracy: 7.14%
# Epoch [21/200], Training Loss: 2.2964, Validation Loss: 2.3048, Accuracy: 7.14%
# Epoch [22/200], Training Loss: 2.3054, Validation Loss: 2.3058, Accuracy: 7.14%
# Epoch [23/200], Training Loss: 2.3035, Validation Loss: 2.3055, Accuracy: 7.14%
# Epoch [24/200], Training Loss: 2.2995, Validation Loss: 2.3061, Accuracy: 11.22%
# Epoch [25/200], Training Loss: 2.2901, Validation Loss: 2.3052, Accuracy: 7.14%
# Epoch [26/200], Training Loss: 2.2860, Validation Loss: 2.3037, Accuracy: 7.14%
# Epoch [27/200], Training Loss: 2.2827, Validation Loss: 2.3032, Accuracy: 7.14%
# Epoch [28/200], Training Loss: 2.2843, Validation Loss: 2.3022, Accuracy: 11.22%
# Epoch [29/200], Training Loss: 2.2819, Validation Loss: 2.3015, Accuracy: 8.16%
# Epoch [30/200], Training Loss: 2.2815, Validation Loss: 2.2997, Accuracy: 11.22%
# Epoch [31/200], Training Loss: 2.2799, Validation Loss: 2.2926, Accuracy: 13.27%
# Epoch [32/200], Training Loss: 2.2779, Validation Loss: 2.2705, Accuracy: 9.18%
# Epoch [33/200], Training Loss: 2.2780, Validation Loss: 2.2975, Accuracy: 10.20%
# Epoch [34/200], Training Loss: 2.2659, Validation Loss: 2.2945, Accuracy: 8.16%
# Epoch [35/200], Training Loss: 2.2858, Validation Loss: 2.3084, Accuracy: 9.18%
# Epoch [36/200], Training Loss: 2.2816, Validation Loss: 2.3074, Accuracy: 9.18%
# Epoch [37/200], Training Loss: 2.2615, Validation Loss: 2.3133, Accuracy: 8.16%
# Epoch [38/200], Training Loss: 2.2693, Validation Loss: 2.3670, Accuracy: 10.20%
# Epoch [39/200], Training Loss: 2.2608, Validation Loss: 2.2528, Accuracy: 11.22%
# Epoch [40/200], Training Loss: 2.2737, Validation Loss: 2.8469, Accuracy: 13.27%
# Epoch [41/200], Training Loss: 2.3477, Validation Loss: 2.2668, Accuracy: 10.20%
# Epoch [42/200], Training Loss: 2.2871, Validation Loss: 2.3572, Accuracy: 8.16%
# Epoch [43/200], Training Loss: 2.3536, Validation Loss: 2.3206, Accuracy: 9.18%
# Epoch [44/200], Training Loss: 2.3097, Validation Loss: 2.3035, Accuracy: 9.18%
# Epoch [45/200], Training Loss: 2.3052, Validation Loss: 2.3050, Accuracy: 14.29%
# Epoch [46/200], Training Loss: 2.2969, Validation Loss: 2.3002, Accuracy: 10.20%
# Epoch [47/200], Training Loss: 2.2896, Validation Loss: 2.2952, Accuracy: 10.20%
# Epoch [48/200], Training Loss: 2.2821, Validation Loss: 2.3055, Accuracy: 12.24%
# Epoch [49/200], Training Loss: 2.2980, Validation Loss: 2.2991, Accuracy: 9.18%
# Epoch [50/200], Training Loss: 2.3089, Validation Loss: 2.3126, Accuracy: 12.24%
# Epoch [51/200], Training Loss: 2.3044, Validation Loss: 2.3092, Accuracy: 13.27%
# Epoch [52/200], Training Loss: 2.3052, Validation Loss: 2.2929, Accuracy: 13.27%
# Epoch [53/200], Training Loss: 2.2949, Validation Loss: 2.2878, Accuracy: 10.20%
# Epoch [54/200], Training Loss: 2.2992, Validation Loss: 2.2814, Accuracy: 9.18%
# Epoch [55/200], Training Loss: 2.2724, Validation Loss: 2.2815, Accuracy: 13.27%
# Epoch [56/200], Training Loss: 2.2590, Validation Loss: 2.2800, Accuracy: 14.29%
# Epoch [57/200], Training Loss: 2.2503, Validation Loss: 2.2900, Accuracy: 14.29%
# Epoch [58/200], Training Loss: 2.2516, Validation Loss: 2.3118, Accuracy: 14.29%
# Epoch [59/200], Training Loss: 2.2522, Validation Loss: 2.2967, Accuracy: 10.20%
# Epoch [60/200], Training Loss: 2.2532, Validation Loss: 2.3062, Accuracy: 10.20%
# Epoch [61/200], Training Loss: 2.2583, Validation Loss: 2.3015, Accuracy: 10.20%
# Epoch [62/200], Training Loss: 2.2611, Validation Loss: 2.3170, Accuracy: 9.18%
# Epoch [63/200], Training Loss: 2.2672, Validation Loss: 2.3143, Accuracy: 9.18%
# Epoch [64/200], Training Loss: 2.2626, Validation Loss: 2.3060, Accuracy: 9.18%
# Epoch [65/200], Training Loss: 2.2651, Validation Loss: 2.3041, Accuracy: 9.18%
# Epoch [66/200], Training Loss: 2.2689, Validation Loss: 2.3049, Accuracy: 9.18%
# Epoch [67/200], Training Loss: 2.2646, Validation Loss: 2.3141, Accuracy: 7.14%
# Epoch [68/200], Training Loss: 2.2685, Validation Loss: 2.3457, Accuracy: 8.16%
# Epoch [69/200], Training Loss: 2.2936, Validation Loss: 2.3150, Accuracy: 9.18%
# Epoch [70/200], Training Loss: 2.2900, Validation Loss: 2.3068, Accuracy: 9.18%
# Epoch [71/200], Training Loss: 2.2843, Validation Loss: 2.2961, Accuracy: 9.18%
# Epoch [72/200], Training Loss: 2.2793, Validation Loss: 2.2961, Accuracy: 9.18%
# Epoch [73/200], Training Loss: 2.2803, Validation Loss: 2.3021, Accuracy: 8.16%
# Epoch [74/200], Training Loss: 2.2787, Validation Loss: 2.3011, Accuracy: 9.18%
# Epoch [75/200], Training Loss: 2.2767, Validation Loss: 2.3045, Accuracy: 9.18%
# Epoch [76/200], Training Loss: 2.2794, Validation Loss: 2.3034, Accuracy: 8.16%
# Epoch [77/200], Training Loss: 2.2809, Validation Loss: 2.3027, Accuracy: 8.16%
# Epoch [78/200], Training Loss: 2.2702, Validation Loss: 2.2925, Accuracy: 11.22%
# Epoch [79/200], Training Loss: 2.2710, Validation Loss: 2.2986, Accuracy: 9.18%
# Epoch [80/200], Training Loss: 2.2732, Validation Loss: 2.3004, Accuracy: 8.16%
# Epoch [81/200], Training Loss: 2.2762, Validation Loss: 2.3152, Accuracy: 11.22%
# Epoch [82/200], Training Loss: 2.2817, Validation Loss: 2.3054, Accuracy: 10.20%
# Epoch [83/200], Training Loss: 2.2814, Validation Loss: 2.2848, Accuracy: 13.27%
# Epoch [84/200], Training Loss: 2.2750, Validation Loss: 2.3136, Accuracy: 6.12%
# Epoch [85/200], Training Loss: 2.2764, Validation Loss: 2.3138, Accuracy: 11.22%
# Epoch [86/200], Training Loss: 2.2644, Validation Loss: 2.3049, Accuracy: 13.27%
# Epoch [87/200], Training Loss: 2.2728, Validation Loss: 2.3114, Accuracy: 10.20%
# Epoch [88/200], Training Loss: 2.2851, Validation Loss: 2.3065, Accuracy: 7.14%
# Epoch [89/200], Training Loss: 2.3165, Validation Loss: 2.2985, Accuracy: 12.24%
# Epoch [90/200], Training Loss: 2.3083, Validation Loss: 2.2986, Accuracy: 9.18%
# Epoch [91/200], Training Loss: 2.3057, Validation Loss: 2.3007, Accuracy: 9.18%
# Epoch [92/200], Training Loss: 2.3073, Validation Loss: 2.2972, Accuracy: 8.16%
# Epoch [93/200], Training Loss: 2.3061, Validation Loss: 2.3043, Accuracy: 7.14%
# Epoch [94/200], Training Loss: 2.3055, Validation Loss: 2.3051, Accuracy: 7.14%
# Epoch [95/200], Training Loss: 2.3064, Validation Loss: 2.3044, Accuracy: 7.14%
# Epoch [96/200], Training Loss: 2.3028, Validation Loss: 2.2999, Accuracy: 10.20%
# Epoch [97/200], Training Loss: 2.3075, Validation Loss: 2.3010, Accuracy: 12.24%
# Epoch [98/200], Training Loss: 2.3051, Validation Loss: 2.3030, Accuracy: 10.20%
# Epoch [99/200], Training Loss: 2.3059, Validation Loss: 2.3036, Accuracy: 7.14%
# Epoch [100/200], Training Loss: 2.3048, Validation Loss: 2.3030, Accuracy: 10.20%
# Epoch [101/200], Training Loss: 2.3027, Validation Loss: 2.3023, Accuracy: 9.18%
# Epoch [102/200], Training Loss: 2.3041, Validation Loss: 2.3041, Accuracy: 12.24%
# Epoch [103/200], Training Loss: 2.3061, Validation Loss: 2.3040, Accuracy: 10.20%
# Epoch [104/200], Training Loss: 2.3037, Validation Loss: 2.3034, Accuracy: 12.24%
# Epoch [105/200], Training Loss: 2.3059, Validation Loss: 2.3000, Accuracy: 12.24%
# Epoch [106/200], Training Loss: 2.3035, Validation Loss: 2.3040, Accuracy: 7.14%
# Epoch [107/200], Training Loss: 2.3059, Validation Loss: 2.3020, Accuracy: 10.20%
# Epoch [108/200], Training Loss: 2.3070, Validation Loss: 2.3058, Accuracy: 7.14%
# Epoch [109/200], Training Loss: 2.3057, Validation Loss: 2.3038, Accuracy: 7.14%
# Epoch [110/200], Training Loss: 2.3042, Validation Loss: 2.3051, Accuracy: 7.14%
# Epoch [111/200], Training Loss: 2.3052, Validation Loss: 2.3011, Accuracy: 12.24%
# Epoch [112/200], Training Loss: 2.3027, Validation Loss: 2.3043, Accuracy: 7.14%
# Epoch [113/200], Training Loss: 2.3033, Validation Loss: 2.3021, Accuracy: 9.18%
# Epoch [114/200], Training Loss: 2.3049, Validation Loss: 2.3051, Accuracy: 7.14%
# Epoch [115/200], Training Loss: 2.3055, Validation Loss: 2.3018, Accuracy: 12.24%
# Epoch [116/200], Training Loss: 2.3049, Validation Loss: 2.3030, Accuracy: 12.24%
# Epoch [117/200], Training Loss: 2.3044, Validation Loss: 2.3019, Accuracy: 12.24%
# Epoch [118/200], Training Loss: 2.3023, Validation Loss: 2.3027, Accuracy: 10.20%
# Epoch [119/200], Training Loss: 2.3044, Validation Loss: 2.3035, Accuracy: 12.24%
# Epoch [120/200], Training Loss: 2.3032, Validation Loss: 2.3029, Accuracy: 7.14%
# Epoch [121/200], Training Loss: 2.3050, Validation Loss: 2.3031, Accuracy: 10.20%
# Epoch [122/200], Training Loss: 2.3046, Validation Loss: 2.3042, Accuracy: 7.14%
# Epoch [123/200], Training Loss: 2.3042, Validation Loss: 2.3028, Accuracy: 10.20%
# Epoch [124/200], Training Loss: 2.3028, Validation Loss: 2.3018, Accuracy: 12.24%
# Epoch [125/200], Training Loss: 2.3054, Validation Loss: 2.3021, Accuracy: 11.22%
# Epoch [126/200], Training Loss: 2.3038, Validation Loss: 2.3017, Accuracy: 12.24%
# Epoch [127/200], Training Loss: 2.3029, Validation Loss: 2.3026, Accuracy: 7.14%
# Epoch [128/200], Training Loss: 2.3033, Validation Loss: 2.3015, Accuracy: 12.24%
# Epoch [129/200], Training Loss: 2.3035, Validation Loss: 2.3016, Accuracy: 12.24%
# Epoch [130/200], Training Loss: 2.3044, Validation Loss: 2.3020, Accuracy: 12.24%
# Epoch [131/200], Training Loss: 2.3031, Validation Loss: 2.3026, Accuracy: 9.18%
# Epoch [132/200], Training Loss: 2.3043, Validation Loss: 2.3032, Accuracy: 10.20%
# Epoch [133/200], Training Loss: 2.3037, Validation Loss: 2.3026, Accuracy: 11.22%
# Epoch [134/200], Training Loss: 2.3047, Validation Loss: 2.3046, Accuracy: 7.14%
# Epoch [135/200], Training Loss: 2.3037, Validation Loss: 2.3011, Accuracy: 12.24%
# Epoch [136/200], Training Loss: 2.3051, Validation Loss: 2.3024, Accuracy: 10.20%
# Epoch [137/200], Training Loss: 2.3042, Validation Loss: 2.3038, Accuracy: 10.20%
# Epoch [138/200], Training Loss: 2.3027, Validation Loss: 2.3035, Accuracy: 7.14%
# Epoch [139/200], Training Loss: 2.3041, Validation Loss: 2.3014, Accuracy: 12.24%
# Epoch [140/200], Training Loss: 2.3030, Validation Loss: 2.3029, Accuracy: 10.20%
# Epoch [141/200], Training Loss: 2.3035, Validation Loss: 2.3038, Accuracy: 9.18%
# Epoch [142/200], Training Loss: 2.3037, Validation Loss: 2.3045, Accuracy: 9.18%
# Epoch [143/200], Training Loss: 2.3050, Validation Loss: 2.3028, Accuracy: 10.20%
# Epoch [144/200], Training Loss: 2.3040, Validation Loss: 2.3027, Accuracy: 12.24%
# Epoch [145/200], Training Loss: 2.3043, Validation Loss: 2.3033, Accuracy: 10.20%
# Epoch [146/200], Training Loss: 2.3043, Validation Loss: 2.3029, Accuracy: 10.20%
# Epoch [147/200], Training Loss: 2.3045, Validation Loss: 2.3026, Accuracy: 10.20%
# Epoch [148/200], Training Loss: 2.3029, Validation Loss: 2.3033, Accuracy: 10.20%
# Epoch [149/200], Training Loss: 2.3032, Validation Loss: 2.3037, Accuracy: 9.18%
# Epoch [150/200], Training Loss: 2.3052, Validation Loss: 2.3040, Accuracy: 7.14%
# Epoch [151/200], Training Loss: 2.3030, Validation Loss: 2.3035, Accuracy: 10.20%
# Epoch [152/200], Training Loss: 2.3048, Validation Loss: 2.3039, Accuracy: 9.18%
# Epoch [153/200], Training Loss: 2.3045, Validation Loss: 2.3033, Accuracy: 7.14%
# Epoch [154/200], Training Loss: 2.3051, Validation Loss: 2.3034, Accuracy: 10.20%
# Epoch [155/200], Training Loss: 2.3052, Validation Loss: 2.3028, Accuracy: 12.24%
# Epoch [156/200], Training Loss: 2.3029, Validation Loss: 2.3039, Accuracy: 9.18%
# Epoch [157/200], Training Loss: 2.3033, Validation Loss: 2.3033, Accuracy: 10.20%
# Epoch [158/200], Training Loss: 2.3042, Validation Loss: 2.3040, Accuracy: 10.20%
# Epoch [159/200], Training Loss: 2.3031, Validation Loss: 2.3029, Accuracy: 9.18%
# Epoch [160/200], Training Loss: 2.3028, Validation Loss: 2.3039, Accuracy: 10.20%
# Epoch [161/200], Training Loss: 2.3039, Validation Loss: 2.3028, Accuracy: 11.22%
# Epoch [162/200], Training Loss: 2.3031, Validation Loss: 2.3020, Accuracy: 12.24%
# Epoch [163/200], Training Loss: 2.3021, Validation Loss: 2.3040, Accuracy: 9.18%
# Epoch [164/200], Training Loss: 2.3035, Validation Loss: 2.3025, Accuracy: 10.20%
# Epoch [165/200], Training Loss: 2.3030, Validation Loss: 2.3030, Accuracy: 12.24%
# Epoch [166/200], Training Loss: 2.3053, Validation Loss: 2.3021, Accuracy: 12.24%
# Epoch [167/200], Training Loss: 2.3032, Validation Loss: 2.3031, Accuracy: 10.20%
# Epoch [168/200], Training Loss: 2.3037, Validation Loss: 2.3031, Accuracy: 7.14%
# Epoch [169/200], Training Loss: 2.3037, Validation Loss: 2.3039, Accuracy: 9.18%
# Epoch [170/200], Training Loss: 2.3043, Validation Loss: 2.3036, Accuracy: 9.18%
# Epoch [171/200], Training Loss: 2.3038, Validation Loss: 2.3033, Accuracy: 9.18%
# Epoch [172/200], Training Loss: 2.3040, Validation Loss: 2.3034, Accuracy: 7.14%
# Epoch [173/200], Training Loss: 2.3032, Validation Loss: 2.3028, Accuracy: 9.18%
# Epoch [174/200], Training Loss: 2.3040, Validation Loss: 2.3028, Accuracy: 12.24%
# Epoch [175/200], Training Loss: 2.3032, Validation Loss: 2.3034, Accuracy: 7.14%
# Epoch [176/200], Training Loss: 2.3025, Validation Loss: 2.3033, Accuracy: 9.18%
# Epoch [177/200], Training Loss: 2.3038, Validation Loss: 2.3031, Accuracy: 12.24%
# Epoch [178/200], Training Loss: 2.3040, Validation Loss: 2.3043, Accuracy: 7.14%
# Epoch [179/200], Training Loss: 2.3030, Validation Loss: 2.3038, Accuracy: 7.14%
# Epoch [180/200], Training Loss: 2.3035, Validation Loss: 2.3035, Accuracy: 7.14%
# Epoch [181/200], Training Loss: 2.3034, Validation Loss: 2.3028, Accuracy: 7.14%
# Epoch [182/200], Training Loss: 2.3023, Validation Loss: 2.3030, Accuracy: 9.18%
# Epoch [183/200], Training Loss: 2.3036, Validation Loss: 2.3030, Accuracy: 10.20%
# Epoch [184/200], Training Loss: 2.3034, Validation Loss: 2.3040, Accuracy: 7.14%
# Epoch [185/200], Training Loss: 2.3043, Validation Loss: 2.3035, Accuracy: 12.24%
# Epoch [186/200], Training Loss: 2.3045, Validation Loss: 2.3031, Accuracy: 9.18%
# Epoch [187/200], Training Loss: 2.3030, Validation Loss: 2.3028, Accuracy: 10.20%
# Epoch [188/200], Training Loss: 2.3023, Validation Loss: 2.3031, Accuracy: 9.18%
# Epoch [189/200], Training Loss: 2.3035, Validation Loss: 2.3033, Accuracy: 7.14%
# Epoch [190/200], Training Loss: 2.3044, Validation Loss: 2.3030, Accuracy: 9.18%
# Epoch [191/200], Training Loss: 2.3046, Validation Loss: 2.3037, Accuracy: 7.14%
# Epoch [192/200], Training Loss: 2.3028, Validation Loss: 2.3025, Accuracy: 8.16%
# Epoch [193/200], Training Loss: 2.3032, Validation Loss: 2.3037, Accuracy: 9.18%
# Epoch [194/200], Training Loss: 2.3046, Validation Loss: 2.3032, Accuracy: 9.18%
# Epoch [195/200], Training Loss: 2.3038, Validation Loss: 2.3035, Accuracy: 9.18%
# Epoch [196/200], Training Loss: 2.3042, Validation Loss: 2.3026, Accuracy: 10.20%
# Epoch [197/200], Training Loss: 2.3040, Validation Loss: 2.3029, Accuracy: 9.18%
# Epoch [198/200], Training Loss: 2.3039, Validation Loss: 2.3025, Accuracy: 9.18%
# Epoch [199/200], Training Loss: 2.3026, Validation Loss: 2.3038, Accuracy: 7.14%
# Epoch [200/200], Training Loss: 2.3035, Validation Loss: 2.3030, Accuracy: 9.18%
# Best Test acc: 14.285714285714286
# Starting Run 2
# Epoch [1/200], Training Loss: 2.3170, Validation Loss: 2.2970, Accuracy: 12.24%
# Epoch [2/200], Training Loss: 2.3055, Validation Loss: 2.2981, Accuracy: 10.20%
# Epoch [3/200], Training Loss: 2.3063, Validation Loss: 2.2982, Accuracy: 14.29%
# Epoch [4/200], Training Loss: 2.3061, Validation Loss: 2.3010, Accuracy: 10.20%
# Epoch [5/200], Training Loss: 2.3046, Validation Loss: 2.2990, Accuracy: 10.20%
# Epoch [6/200], Training Loss: 2.3048, Validation Loss: 2.3004, Accuracy: 12.24%
# Epoch [7/200], Training Loss: 2.3048, Validation Loss: 2.2991, Accuracy: 14.29%
# Epoch [8/200], Training Loss: 2.3051, Validation Loss: 2.2990, Accuracy: 10.20%
# Epoch [9/200], Training Loss: 2.3045, Validation Loss: 2.3003, Accuracy: 14.29%
# Epoch [10/200], Training Loss: 2.3051, Validation Loss: 2.3001, Accuracy: 14.29%
# Epoch [11/200], Training Loss: 2.3045, Validation Loss: 2.2997, Accuracy: 10.20%
# Epoch [12/200], Training Loss: 2.3040, Validation Loss: 2.2997, Accuracy: 10.20%
# Epoch [13/200], Training Loss: 2.3041, Validation Loss: 2.3000, Accuracy: 10.20%
# Epoch [14/200], Training Loss: 2.3038, Validation Loss: 2.3003, Accuracy: 10.20%
# Epoch [15/200], Training Loss: 2.3043, Validation Loss: 2.3011, Accuracy: 14.29%
# Epoch [16/200], Training Loss: 2.3046, Validation Loss: 2.3013, Accuracy: 10.20%
# Epoch [17/200], Training Loss: 2.3047, Validation Loss: 2.3024, Accuracy: 14.29%
# Epoch [18/200], Training Loss: 2.3038, Validation Loss: 2.2999, Accuracy: 14.29%
# Epoch [19/200], Training Loss: 2.3044, Validation Loss: 2.3013, Accuracy: 10.20%
# Epoch [20/200], Training Loss: 2.3038, Validation Loss: 2.2999, Accuracy: 10.20%
# Epoch [21/200], Training Loss: 2.3038, Validation Loss: 2.2944, Accuracy: 11.22%
# Epoch [22/200], Training Loss: 2.2998, Validation Loss: 2.3015, Accuracy: 14.29%
# Epoch [23/200], Training Loss: 2.3014, Validation Loss: 2.3043, Accuracy: 13.27%
# Epoch [24/200], Training Loss: 2.2947, Validation Loss: 2.3020, Accuracy: 12.24%
# Epoch [25/200], Training Loss: 2.3103, Validation Loss: 2.3022, Accuracy: 12.24%
# Epoch [26/200], Training Loss: 2.3042, Validation Loss: 2.3003, Accuracy: 12.24%
# Epoch [27/200], Training Loss: 2.3037, Validation Loss: 2.2997, Accuracy: 12.24%
# Epoch [28/200], Training Loss: 2.3011, Validation Loss: 2.3020, Accuracy: 7.14%
# Epoch [29/200], Training Loss: 2.2972, Validation Loss: 2.2992, Accuracy: 10.20%
# Epoch [30/200], Training Loss: 2.2926, Validation Loss: 2.2980, Accuracy: 13.27%
# Epoch [31/200], Training Loss: 2.3015, Validation Loss: 2.3064, Accuracy: 12.24%
# Epoch [32/200], Training Loss: 2.2894, Validation Loss: 2.3372, Accuracy: 13.27%
# Epoch [33/200], Training Loss: 2.4939, Validation Loss: 2.3032, Accuracy: 7.14%
# Epoch [34/200], Training Loss: 2.3095, Validation Loss: 2.3052, Accuracy: 7.14%
# Epoch [35/200], Training Loss: 2.3030, Validation Loss: 2.3055, Accuracy: 7.14%
# Epoch [36/200], Training Loss: 2.2916, Validation Loss: 2.3085, Accuracy: 9.18%
# Epoch [37/200], Training Loss: 2.2776, Validation Loss: 2.2909, Accuracy: 15.31%
# Epoch [38/200], Training Loss: 2.2634, Validation Loss: 2.2669, Accuracy: 13.27%
# Epoch [39/200], Training Loss: 2.2485, Validation Loss: 2.2858, Accuracy: 12.24%
# Epoch [40/200], Training Loss: 2.2606, Validation Loss: 2.2780, Accuracy: 12.24%
# Epoch [41/200], Training Loss: 2.2434, Validation Loss: 2.3076, Accuracy: 10.20%
# Epoch [42/200], Training Loss: 2.2516, Validation Loss: 2.3242, Accuracy: 7.14%
# Epoch [43/200], Training Loss: 2.2061, Validation Loss: 2.2837, Accuracy: 8.16%
# Epoch [44/200], Training Loss: 2.2140, Validation Loss: 2.3198, Accuracy: 8.16%
# Epoch [45/200], Training Loss: 2.2079, Validation Loss: 2.3404, Accuracy: 7.14%
# Epoch [46/200], Training Loss: 2.1798, Validation Loss: 2.3498, Accuracy: 8.16%
# Epoch [47/200], Training Loss: 2.2019, Validation Loss: 2.3711, Accuracy: 6.12%
# Epoch [48/200], Training Loss: 2.1749, Validation Loss: 2.3477, Accuracy: 8.16%
# Epoch [49/200], Training Loss: 2.1846, Validation Loss: 2.4178, Accuracy: 6.12%
# Epoch [50/200], Training Loss: 2.1801, Validation Loss: 2.3671, Accuracy: 9.18%
# Epoch [51/200], Training Loss: 2.1360, Validation Loss: 2.3606, Accuracy: 9.18%
# Epoch [52/200], Training Loss: 2.2518, Validation Loss: 2.3125, Accuracy: 8.16%
# Epoch [53/200], Training Loss: 2.2182, Validation Loss: 2.3430, Accuracy: 7.14%
# Epoch [54/200], Training Loss: 2.1847, Validation Loss: 2.3153, Accuracy: 9.18%
# Epoch [55/200], Training Loss: 2.1579, Validation Loss: 2.4147, Accuracy: 9.18%
# Epoch [56/200], Training Loss: 2.1339, Validation Loss: 2.3863, Accuracy: 7.14%
# Epoch [57/200], Training Loss: 2.1391, Validation Loss: 2.4113, Accuracy: 6.12%
# Epoch [58/200], Training Loss: 2.1990, Validation Loss: 2.3270, Accuracy: 7.14%
# Epoch [59/200], Training Loss: 2.1402, Validation Loss: 2.4303, Accuracy: 5.10%
# Epoch [60/200], Training Loss: 2.1445, Validation Loss: 2.3763, Accuracy: 10.20%
# Epoch [61/200], Training Loss: 2.1511, Validation Loss: 2.3694, Accuracy: 8.16%
# Epoch [62/200], Training Loss: 2.1228, Validation Loss: 2.4110, Accuracy: 8.16%
# Epoch [63/200], Training Loss: 2.1009, Validation Loss: 2.4394, Accuracy: 7.14%
# Epoch [64/200], Training Loss: 2.1333, Validation Loss: 2.3664, Accuracy: 7.14%
# Epoch [65/200], Training Loss: 2.0762, Validation Loss: 2.4521, Accuracy: 10.20%
# Epoch [66/200], Training Loss: 2.1236, Validation Loss: 2.4035, Accuracy: 8.16%
# Epoch [67/200], Training Loss: 2.2084, Validation Loss: 2.2947, Accuracy: 8.16%
# Epoch [68/200], Training Loss: 2.1421, Validation Loss: 2.3823, Accuracy: 6.12%
# Epoch [69/200], Training Loss: 2.0901, Validation Loss: 2.3723, Accuracy: 6.12%
# Epoch [70/200], Training Loss: 2.0399, Validation Loss: 2.4236, Accuracy: 6.12%
# Epoch [71/200], Training Loss: 1.9963, Validation Loss: 2.4634, Accuracy: 7.14%
# Epoch [72/200], Training Loss: 2.0838, Validation Loss: 2.3339, Accuracy: 7.14%
# Epoch [73/200], Training Loss: 2.2688, Validation Loss: 2.8298, Accuracy: 5.10%
# Epoch [74/200], Training Loss: 2.3239, Validation Loss: 2.2965, Accuracy: 5.10%
# Epoch [75/200], Training Loss: 2.1710, Validation Loss: 2.3487, Accuracy: 4.08%
# Epoch [76/200], Training Loss: 2.1631, Validation Loss: 2.3595, Accuracy: 5.10%
# Epoch [77/200], Training Loss: 2.1414, Validation Loss: 2.3982, Accuracy: 7.14%
# Epoch [78/200], Training Loss: 2.1291, Validation Loss: 2.3968, Accuracy: 4.08%
# Epoch [79/200], Training Loss: 2.1313, Validation Loss: 2.4824, Accuracy: 10.20%
# Epoch [80/200], Training Loss: 2.1109, Validation Loss: 2.3878, Accuracy: 5.10%
# Epoch [81/200], Training Loss: 2.0927, Validation Loss: 2.4076, Accuracy: 6.12%
# Epoch [82/200], Training Loss: 2.1161, Validation Loss: 2.3825, Accuracy: 9.18%
# Epoch [83/200], Training Loss: 2.0604, Validation Loss: 2.4417, Accuracy: 11.22%
# Epoch [84/200], Training Loss: 2.0544, Validation Loss: 2.5094, Accuracy: 7.14%
# Epoch [85/200], Training Loss: 2.0569, Validation Loss: 2.5780, Accuracy: 9.18%
# Epoch [86/200], Training Loss: 2.0908, Validation Loss: 2.5029, Accuracy: 14.29%
# Epoch [87/200], Training Loss: 2.0752, Validation Loss: 2.4360, Accuracy: 6.12%
# Epoch [88/200], Training Loss: 2.0509, Validation Loss: 2.4242, Accuracy: 10.20%
# Epoch [89/200], Training Loss: 2.0726, Validation Loss: 2.4754, Accuracy: 11.22%
# Epoch [90/200], Training Loss: 2.0452, Validation Loss: 2.4248, Accuracy: 12.24%
# Epoch [91/200], Training Loss: 2.0444, Validation Loss: 2.4585, Accuracy: 12.24%
# Epoch [92/200], Training Loss: 2.0023, Validation Loss: 2.5136, Accuracy: 11.22%
# Epoch [93/200], Training Loss: 1.9457, Validation Loss: 2.5605, Accuracy: 10.20%
# Epoch [94/200], Training Loss: 1.9815, Validation Loss: 2.6228, Accuracy: 16.33%
# Epoch [95/200], Training Loss: 2.0307, Validation Loss: 2.4754, Accuracy: 8.16%
# Epoch [96/200], Training Loss: 2.0645, Validation Loss: 2.4688, Accuracy: 12.24%
# Epoch [97/200], Training Loss: 2.0006, Validation Loss: 2.5850, Accuracy: 12.24%
# Epoch [98/200], Training Loss: 1.9718, Validation Loss: 2.5367, Accuracy: 11.22%
# Epoch [99/200], Training Loss: 1.9979, Validation Loss: 2.5723, Accuracy: 11.22%
# Epoch [100/200], Training Loss: 1.9365, Validation Loss: 2.6013, Accuracy: 9.18%
# Epoch [101/200], Training Loss: 1.9437, Validation Loss: 2.7086, Accuracy: 11.22%
# Epoch [102/200], Training Loss: 1.9675, Validation Loss: 2.6919, Accuracy: 13.27%
# Epoch [103/200], Training Loss: 1.9204, Validation Loss: 2.6437, Accuracy: 11.22%
# Epoch [104/200], Training Loss: 1.8792, Validation Loss: 2.8554, Accuracy: 10.20%
# Epoch [105/200], Training Loss: 1.9031, Validation Loss: 2.8421, Accuracy: 12.24%
# Epoch [106/200], Training Loss: 2.0009, Validation Loss: 2.5286, Accuracy: 13.27%
# Epoch [107/200], Training Loss: 2.1442, Validation Loss: 2.3660, Accuracy: 12.24%
# Epoch [108/200], Training Loss: 2.2127, Validation Loss: 2.4613, Accuracy: 11.22%
# Epoch [109/200], Training Loss: 2.2778, Validation Loss: 2.2713, Accuracy: 11.22%
# Epoch [110/200], Training Loss: 2.0966, Validation Loss: 2.4098, Accuracy: 10.20%
# Epoch [111/200], Training Loss: 2.0251, Validation Loss: 2.4451, Accuracy: 10.20%
# Epoch [112/200], Training Loss: 1.9749, Validation Loss: 2.5479, Accuracy: 7.14%
# Epoch [113/200], Training Loss: 1.9711, Validation Loss: 2.4233, Accuracy: 6.12%
# Epoch [114/200], Training Loss: 1.9555, Validation Loss: 2.6486, Accuracy: 12.24%
# Epoch [115/200], Training Loss: 1.9198, Validation Loss: 2.5962, Accuracy: 7.14%
# Epoch [116/200], Training Loss: 1.9055, Validation Loss: 2.6578, Accuracy: 9.18%
# Epoch [117/200], Training Loss: 1.9266, Validation Loss: 2.7094, Accuracy: 9.18%
# Epoch [118/200], Training Loss: 1.8561, Validation Loss: 2.9022, Accuracy: 13.27%
# Epoch [119/200], Training Loss: 1.9181, Validation Loss: 2.8093, Accuracy: 11.22%
# Epoch [120/200], Training Loss: 1.8730, Validation Loss: 2.8625, Accuracy: 13.27%
# Epoch [121/200], Training Loss: 1.8862, Validation Loss: 2.8422, Accuracy: 15.31%
# Epoch [122/200], Training Loss: 1.9309, Validation Loss: 2.8723, Accuracy: 13.27%
# Epoch [123/200], Training Loss: 1.8442, Validation Loss: 2.7699, Accuracy: 12.24%
# Epoch [124/200], Training Loss: 1.9553, Validation Loss: 2.8991, Accuracy: 13.27%
# Epoch [125/200], Training Loss: 1.8965, Validation Loss: 2.7630, Accuracy: 15.31%
# Epoch [126/200], Training Loss: 1.8578, Validation Loss: 2.8462, Accuracy: 12.24%
# Epoch [127/200], Training Loss: 2.0129, Validation Loss: 2.5268, Accuracy: 11.22%
# Epoch [128/200], Training Loss: 2.0685, Validation Loss: 2.4441, Accuracy: 12.24%
# Epoch [129/200], Training Loss: 1.8820, Validation Loss: 2.4806, Accuracy: 15.31%
# Epoch [130/200], Training Loss: 1.8255, Validation Loss: 2.6462, Accuracy: 13.27%
# Epoch [131/200], Training Loss: 1.7858, Validation Loss: 2.6250, Accuracy: 14.29%
# Epoch [132/200], Training Loss: 1.8072, Validation Loss: 2.9014, Accuracy: 8.16%
# Epoch [133/200], Training Loss: 1.7740, Validation Loss: 2.7035, Accuracy: 13.27%
# Epoch [134/200], Training Loss: 1.7619, Validation Loss: 2.7028, Accuracy: 13.27%
# Epoch [135/200], Training Loss: 2.2564, Validation Loss: 2.9006, Accuracy: 15.31%
# Epoch [136/200], Training Loss: 2.7659, Validation Loss: 2.4491, Accuracy: 12.24%
# Epoch [137/200], Training Loss: 2.3234, Validation Loss: 2.3329, Accuracy: 12.24%
# Epoch [138/200], Training Loss: 2.2989, Validation Loss: 2.3206, Accuracy: 8.16%
# Epoch [139/200], Training Loss: 2.2896, Validation Loss: 2.3042, Accuracy: 13.27%
# Epoch [140/200], Training Loss: 2.2798, Validation Loss: 2.3102, Accuracy: 7.14%
# Epoch [141/200], Training Loss: 2.2824, Validation Loss: 2.3078, Accuracy: 8.16%
# Epoch [142/200], Training Loss: 2.2741, Validation Loss: 2.3138, Accuracy: 8.16%
# Epoch [143/200], Training Loss: 2.2709, Validation Loss: 2.3144, Accuracy: 14.29%
# Epoch [144/200], Training Loss: 2.2587, Validation Loss: 2.3050, Accuracy: 11.22%
# Epoch [145/200], Training Loss: 2.2511, Validation Loss: 2.3800, Accuracy: 13.27%
# Epoch [146/200], Training Loss: 2.2330, Validation Loss: 2.3786, Accuracy: 9.18%
# Epoch [147/200], Training Loss: 2.2462, Validation Loss: 2.3958, Accuracy: 16.33%
# Epoch [148/200], Training Loss: 2.2176, Validation Loss: 2.2874, Accuracy: 11.22%
# Epoch [149/200], Training Loss: 2.2172, Validation Loss: 2.3414, Accuracy: 12.24%
# Epoch [150/200], Training Loss: 2.1957, Validation Loss: 2.3874, Accuracy: 11.22%
# Epoch [151/200], Training Loss: 2.1910, Validation Loss: 2.3888, Accuracy: 13.27%
# Epoch [152/200], Training Loss: 2.1954, Validation Loss: 2.3990, Accuracy: 12.24%
# Epoch [153/200], Training Loss: 2.1940, Validation Loss: 2.4454, Accuracy: 12.24%
# Epoch [154/200], Training Loss: 2.1784, Validation Loss: 2.4537, Accuracy: 16.33%
# Epoch [155/200], Training Loss: 2.1869, Validation Loss: 2.4335, Accuracy: 6.12%
# Epoch [156/200], Training Loss: 2.1538, Validation Loss: 2.4713, Accuracy: 7.14%
# Epoch [157/200], Training Loss: 2.1438, Validation Loss: 2.4486, Accuracy: 9.18%
# Epoch [158/200], Training Loss: 2.1223, Validation Loss: 2.5053, Accuracy: 12.24%
# Epoch [159/200], Training Loss: 2.1126, Validation Loss: 2.5119, Accuracy: 13.27%
# Epoch [160/200], Training Loss: 2.0966, Validation Loss: 2.5068, Accuracy: 12.24%
# Epoch [161/200], Training Loss: 2.0869, Validation Loss: 2.5666, Accuracy: 9.18%
# Epoch [162/200], Training Loss: 2.0762, Validation Loss: 2.6457, Accuracy: 11.22%
# Epoch [163/200], Training Loss: 2.1277, Validation Loss: 2.3370, Accuracy: 10.20%
# Epoch [164/200], Training Loss: 2.2559, Validation Loss: 2.3574, Accuracy: 7.14%
# Epoch [165/200], Training Loss: 2.2850, Validation Loss: 2.3154, Accuracy: 14.29%
# Epoch [166/200], Training Loss: 2.2688, Validation Loss: 2.3289, Accuracy: 7.14%
# Epoch [167/200], Training Loss: 2.2327, Validation Loss: 2.3418, Accuracy: 8.16%
# Epoch [168/200], Training Loss: 2.2250, Validation Loss: 2.3380, Accuracy: 10.20%
# Epoch [169/200], Training Loss: 2.1822, Validation Loss: 2.3668, Accuracy: 8.16%
# Epoch [170/200], Training Loss: 2.1560, Validation Loss: 2.3374, Accuracy: 9.18%
# Epoch [171/200], Training Loss: 2.1517, Validation Loss: 2.3761, Accuracy: 9.18%
# Epoch [172/200], Training Loss: 2.1410, Validation Loss: 2.3949, Accuracy: 11.22%
# Epoch [173/200], Training Loss: 2.1183, Validation Loss: 2.3863, Accuracy: 10.20%
# Epoch [174/200], Training Loss: 2.1271, Validation Loss: 2.4045, Accuracy: 9.18%
# Epoch [175/200], Training Loss: 2.1477, Validation Loss: 2.4334, Accuracy: 10.20%
# Epoch [176/200], Training Loss: 2.1129, Validation Loss: 2.4614, Accuracy: 14.29%
# Epoch [177/200], Training Loss: 2.0968, Validation Loss: 2.4155, Accuracy: 14.29%
# Epoch [178/200], Training Loss: 2.1306, Validation Loss: 2.3276, Accuracy: 12.24%
# Epoch [179/200], Training Loss: 2.1143, Validation Loss: 2.3804, Accuracy: 11.22%
# Epoch [180/200], Training Loss: 2.1306, Validation Loss: 2.4206, Accuracy: 11.22%
# Epoch [181/200], Training Loss: 2.0620, Validation Loss: 2.4080, Accuracy: 13.27%
# Epoch [182/200], Training Loss: 2.1125, Validation Loss: 2.4706, Accuracy: 9.18%
# Epoch [183/200], Training Loss: 2.0454, Validation Loss: 2.5236, Accuracy: 13.27%
# Epoch [184/200], Training Loss: 2.0568, Validation Loss: 2.5459, Accuracy: 11.22%
# Epoch [185/200], Training Loss: 2.0808, Validation Loss: 2.4599, Accuracy: 14.29%
# Epoch [186/200], Training Loss: 2.0523, Validation Loss: 2.5004, Accuracy: 13.27%
# Epoch [187/200], Training Loss: 2.0149, Validation Loss: 2.5783, Accuracy: 14.29%
# Epoch [188/200], Training Loss: 2.0324, Validation Loss: 2.4588, Accuracy: 14.29%
# Epoch [189/200], Training Loss: 2.0123, Validation Loss: 2.4986, Accuracy: 14.29%
# Epoch [190/200], Training Loss: 1.9724, Validation Loss: 2.6151, Accuracy: 14.29%
# Epoch [191/200], Training Loss: 1.9777, Validation Loss: 2.5762, Accuracy: 9.18%
# Epoch [192/200], Training Loss: 2.0100, Validation Loss: 2.5867, Accuracy: 12.24%
# Epoch [193/200], Training Loss: 1.9657, Validation Loss: 2.6420, Accuracy: 11.22%
# Epoch [194/200], Training Loss: 2.0031, Validation Loss: 2.6601, Accuracy: 9.18%
# Epoch [195/200], Training Loss: 2.0284, Validation Loss: 2.7006, Accuracy: 8.16%
# Epoch [196/200], Training Loss: 1.9479, Validation Loss: 2.6807, Accuracy: 12.24%
# Epoch [197/200], Training Loss: 1.9143, Validation Loss: 2.7393, Accuracy: 11.22%
# Epoch [198/200], Training Loss: 1.9211, Validation Loss: 2.7886, Accuracy: 18.37%
# Epoch [199/200], Training Loss: 2.1692, Validation Loss: 2.5389, Accuracy: 8.16%
# Epoch [200/200], Training Loss: 2.4953, Validation Loss: 2.4680, Accuracy: 7.14%
# Best Test acc: 18.367346938775512
# Starting Run 3
# Epoch [1/200], Training Loss: 2.3091, Validation Loss: 2.2997, Accuracy: 14.29%
# Epoch [2/200], Training Loss: 2.3052, Validation Loss: 2.2976, Accuracy: 14.29%
# Epoch [3/200], Training Loss: 2.3052, Validation Loss: 2.3011, Accuracy: 14.29%
# Epoch [4/200], Training Loss: 2.3075, Validation Loss: 2.2993, Accuracy: 14.29%
# Epoch [5/200], Training Loss: 2.3058, Validation Loss: 2.2995, Accuracy: 14.29%
# Epoch [6/200], Training Loss: 2.3059, Validation Loss: 2.2982, Accuracy: 12.24%
# Epoch [7/200], Training Loss: 2.3043, Validation Loss: 2.2994, Accuracy: 12.24%
# Epoch [8/200], Training Loss: 2.3049, Validation Loss: 2.3008, Accuracy: 7.14%
# Epoch [9/200], Training Loss: 2.3043, Validation Loss: 2.3008, Accuracy: 12.24%
# Epoch [10/200], Training Loss: 2.3041, Validation Loss: 2.3005, Accuracy: 14.29%
# Epoch [11/200], Training Loss: 2.3046, Validation Loss: 2.3003, Accuracy: 14.29%
# Epoch [12/200], Training Loss: 2.3044, Validation Loss: 2.3014, Accuracy: 7.14%
# Epoch [13/200], Training Loss: 2.3042, Validation Loss: 2.3012, Accuracy: 12.24%
# Epoch [14/200], Training Loss: 2.3038, Validation Loss: 2.3017, Accuracy: 7.14%
# Epoch [15/200], Training Loss: 2.3034, Validation Loss: 2.3012, Accuracy: 7.14%
# Epoch [16/200], Training Loss: 2.3340, Validation Loss: 2.3072, Accuracy: 12.24%
# Epoch [17/200], Training Loss: 2.3202, Validation Loss: 2.3071, Accuracy: 7.14%
# Epoch [18/200], Training Loss: 2.3061, Validation Loss: 2.3027, Accuracy: 7.14%
# Epoch [19/200], Training Loss: 2.3077, Validation Loss: 2.3011, Accuracy: 7.14%
# Epoch [20/200], Training Loss: 2.3053, Validation Loss: 2.3006, Accuracy: 12.24%
# Epoch [21/200], Training Loss: 2.3044, Validation Loss: 2.3029, Accuracy: 10.20%
# Epoch [22/200], Training Loss: 2.3048, Validation Loss: 2.3013, Accuracy: 14.29%
# Epoch [23/200], Training Loss: 2.3045, Validation Loss: 2.3006, Accuracy: 12.24%
# Epoch [24/200], Training Loss: 2.3053, Validation Loss: 2.3007, Accuracy: 12.24%
# Epoch [25/200], Training Loss: 2.3048, Validation Loss: 2.3008, Accuracy: 12.24%
# Epoch [26/200], Training Loss: 2.3035, Validation Loss: 2.3007, Accuracy: 12.24%
# Epoch [27/200], Training Loss: 2.3034, Validation Loss: 2.3003, Accuracy: 12.24%
# Epoch [28/200], Training Loss: 2.3047, Validation Loss: 2.3022, Accuracy: 7.14%
# Epoch [29/200], Training Loss: 2.3039, Validation Loss: 2.3009, Accuracy: 14.29%
# Epoch [30/200], Training Loss: 2.3043, Validation Loss: 2.3004, Accuracy: 12.24%
# Epoch [31/200], Training Loss: 2.3040, Validation Loss: 2.3013, Accuracy: 12.24%
# Epoch [32/200], Training Loss: 2.3040, Validation Loss: 2.3016, Accuracy: 12.24%
# Epoch [33/200], Training Loss: 2.3029, Validation Loss: 2.3016, Accuracy: 12.24%
# Epoch [34/200], Training Loss: 2.3040, Validation Loss: 2.3016, Accuracy: 12.24%
# Epoch [35/200], Training Loss: 2.3032, Validation Loss: 2.3014, Accuracy: 14.29%
# Epoch [36/200], Training Loss: 2.3045, Validation Loss: 2.3020, Accuracy: 12.24%
# Epoch [37/200], Training Loss: 2.3044, Validation Loss: 2.3021, Accuracy: 12.24%
# Epoch [38/200], Training Loss: 2.3044, Validation Loss: 2.3015, Accuracy: 12.24%
# Epoch [39/200], Training Loss: 2.3045, Validation Loss: 2.3028, Accuracy: 11.22%
# Epoch [40/200], Training Loss: 2.3048, Validation Loss: 2.3000, Accuracy: 12.24%
# Epoch [41/200], Training Loss: 2.3036, Validation Loss: 2.3014, Accuracy: 7.14%
# Epoch [42/200], Training Loss: 2.3030, Validation Loss: 2.3012, Accuracy: 7.14%
# Epoch [43/200], Training Loss: 2.3041, Validation Loss: 2.3019, Accuracy: 7.14%
# Epoch [44/200], Training Loss: 2.3040, Validation Loss: 2.3011, Accuracy: 12.24%
# Epoch [45/200], Training Loss: 2.3040, Validation Loss: 2.3009, Accuracy: 14.29%
# Epoch [46/200], Training Loss: 2.3031, Validation Loss: 2.3018, Accuracy: 14.29%
# Epoch [47/200], Training Loss: 2.3034, Validation Loss: 2.3011, Accuracy: 14.29%
# Epoch [48/200], Training Loss: 2.3032, Validation Loss: 2.3008, Accuracy: 12.24%
# Epoch [49/200], Training Loss: 2.3031, Validation Loss: 2.3015, Accuracy: 12.24%
# Epoch [50/200], Training Loss: 2.3043, Validation Loss: 2.3023, Accuracy: 10.20%
# Epoch [51/200], Training Loss: 2.3035, Validation Loss: 2.3014, Accuracy: 7.14%
# Epoch [52/200], Training Loss: 2.3039, Validation Loss: 2.3009, Accuracy: 12.24%
# Epoch [53/200], Training Loss: 2.3029, Validation Loss: 2.3014, Accuracy: 7.14%
# Epoch [54/200], Training Loss: 2.3035, Validation Loss: 2.3016, Accuracy: 12.24%
# Epoch [55/200], Training Loss: 2.3035, Validation Loss: 2.3017, Accuracy: 7.14%
# Epoch [56/200], Training Loss: 2.3035, Validation Loss: 2.3016, Accuracy: 14.29%
# Epoch [57/200], Training Loss: 2.3042, Validation Loss: 2.3022, Accuracy: 12.24%
# Epoch [58/200], Training Loss: 2.3036, Validation Loss: 2.3013, Accuracy: 12.24%
# Epoch [59/200], Training Loss: 2.3033, Validation Loss: 2.3011, Accuracy: 12.24%
# Epoch [60/200], Training Loss: 2.3041, Validation Loss: 2.3016, Accuracy: 14.29%
# Epoch [61/200], Training Loss: 2.3038, Validation Loss: 2.3007, Accuracy: 14.29%
# Epoch [62/200], Training Loss: 2.3037, Validation Loss: 2.3011, Accuracy: 12.24%
# Epoch [63/200], Training Loss: 2.3035, Validation Loss: 2.3006, Accuracy: 14.29%
# Epoch [64/200], Training Loss: 2.3031, Validation Loss: 2.3006, Accuracy: 14.29%
# Epoch [65/200], Training Loss: 2.3038, Validation Loss: 2.3015, Accuracy: 12.24%
# Epoch [66/200], Training Loss: 2.3032, Validation Loss: 2.3007, Accuracy: 12.24%
# Epoch [67/200], Training Loss: 2.3032, Validation Loss: 2.3008, Accuracy: 12.24%
# Epoch [68/200], Training Loss: 2.3038, Validation Loss: 2.3011, Accuracy: 12.24%
# Epoch [69/200], Training Loss: 2.3035, Validation Loss: 2.3007, Accuracy: 12.24%
# Epoch [70/200], Training Loss: 2.3030, Validation Loss: 2.3010, Accuracy: 12.24%
# Epoch [71/200], Training Loss: 2.3032, Validation Loss: 2.3011, Accuracy: 12.24%
# Epoch [72/200], Training Loss: 2.3036, Validation Loss: 2.3012, Accuracy: 12.24%
# Epoch [73/200], Training Loss: 2.3036, Validation Loss: 2.3006, Accuracy: 12.24%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20532\827901760.py in <module>
#      29             outputs = model(x1)
#      30             loss = criterion(outputs, labels.long())
# ---> 31             loss.backward()
#      32             optimizer.step()
#      33             total_train_loss += loss.item()
#
# c:\Users\denis\anaconda3\lib\site-packages\torch\_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     485                 inputs=inputs,
#     486             )
# --> 487         torch.autograd.backward(
#     488             self, gradient, retain_graph, create_graph, inputs=inputs
#     489         )
#
# c:\Users\denis\anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     198     # some Python versions print out the first line of a multi-line function
#     199     # calls in the traceback and some print out the last line
# --> 200     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
model = DualInputLSTM(2, 128, 3)

# Load the saved model weights
model.load_state_dict(torch.load('best_model-90acc.pth'))

model.eval()
correct = 0
total = 0
index = 0
with torch.no_grad():

    for x1, labels in test_loader:
        # if index == 2:
        #     print(x1)
        outputs = model(x1)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        index = index + 1

print(f"Test Accuracy: {100 * correct / total:.2f}%")
# Out:
# Test Accuracy: 90.82%
